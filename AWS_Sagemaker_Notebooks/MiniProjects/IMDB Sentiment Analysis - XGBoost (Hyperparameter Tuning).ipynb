# %% [markdown]
# # Sentiment Analysis
#
# ## Using XGBoost in SageMaker
#
# _Deep Learning Nanodegree Program | Deployment_
#
# ---
#
# In this example of using Amazon's SageMaker service we will construct a random tree model to predict the sentiment of a movie review. You may have seen a version of this example in a pervious lesson although it would have been done using the sklearn package. Instead, we will be using the XGBoost package as it is provided to us by Amazon.
#
# ## Instructions
#
# Some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this notebook. You will not need to modify the included code beyond what is requested. Sections that begin with '**TODO**' in the header indicate that you need to complete or implement some portion within them. Instructions will be provided for each section and the specifics of the implementation are marked in the code block with a `# TODO: ...` comment. Please be sure to read the instructions carefully!
#
# In addition to implementing code, there will be questions for you to answer which relate to the task and your implementation. Each section where you will answer a question is preceded by a '**Question:**' header. Carefully read each question and provide your answer below the '**Answer:**' header by editing the Markdown cell.
#
# > **Note**: Code and Markdown cells can be executed using the **Shift+Enter** keyboard shortcut. In addition, a cell can be edited by typically clicking it (double-click for Markdown cells) or by pressing **Enter** while it is highlighted.

# %% [markdown]
# ## Step 1: Downloading the data
#
# The dataset we are going to use is very popular among researchers in Natural Language Processing, usually referred to as the [IMDb dataset](http://ai.stanford.edu/~amaas/data/sentiment/). It consists of movie reviews from the website [imdb.com](http://www.imdb.com/), each labeled as either '**pos**itive', if the reviewer enjoyed the film, or '**neg**ative' otherwise.
#
# > Maas, Andrew L., et al. [Learning Word Vectors for Sentiment Analysis](http://ai.stanford.edu/~amaas/data/sentiment/). In _Proceedings of the 49th Annual Meeting of the Association for Computational Linguistics: Human Language Technologies_. Association for Computational Linguistics, 2011.
#
# We begin by using some Jupyter Notebook magic to download and extract the dataset.

# %%
# %mkdir ../data
# !wget -O ../data/aclImdb_v1.tar.gz http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# !tar -zxf ../data/aclImdb_v1.tar.gz -C ../data
# Out:
# mkdir: cannot create directory ‘../data’: File exists
# --2020-02-05 04:11:15--  http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# Resolving ai.stanford.edu (ai.stanford.edu)... 171.64.68.10
# Connecting to ai.stanford.edu (ai.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 84125825 (80M) [application/x-gzip]
# Saving to: ‘../data/aclImdb_v1.tar.gz’
#
# ../data/aclImdb_v1. 100%[===================>]  80.23M  24.1MB/s    in 4.1s
#
# 2020-02-05 04:11:19 (19.5 MB/s) - ‘../data/aclImdb_v1.tar.gz’ saved [84125825/84125825]

# %% [markdown]
# ## Step 2: Preparing the data
#
# The data we have downloaded is split into various files, each of which contains a single review. It will be much easier going forward if we combine these individual files into two large files, one for training and one for testing.

# %%
import os
import glob

def read_imdb_data(data_dir='../data/aclImdb'):
    data = {}
    labels = {}
    
    for data_type in ['train', 'test']:
        data[data_type] = {}
        labels[data_type] = {}
        
        for sentiment in ['pos', 'neg']:
            data[data_type][sentiment] = []
            labels[data_type][sentiment] = []
            
            path = os.path.join(data_dir, data_type, sentiment, '*.txt')
            files = glob.glob(path)
            
            for f in files:
                with open(f) as review:
                    data[data_type][sentiment].append(review.read())
                    # Here we represent a positive review by '1' and a negative review by '0'
                    labels[data_type][sentiment].append(1 if sentiment == 'pos' else 0)
                    
            assert len(data[data_type][sentiment]) == len(labels[data_type][sentiment]), \
                    "{}/{} data size does not match labels size".format(data_type, sentiment)
                
    return data, labels

# %%
data, labels = read_imdb_data()
print("IMDB reviews: train = {} pos / {} neg, test = {} pos / {} neg".format(
            len(data['train']['pos']), len(data['train']['neg']),
            len(data['test']['pos']), len(data['test']['neg'])))
# Out:
# IMDB reviews: train = 12500 pos / 12500 neg, test = 12500 pos / 12500 neg

# %%
from sklearn.utils import shuffle

def prepare_imdb_data(data, labels):
    """Prepare training and test sets from IMDb movie reviews."""
    
    #Combine positive and negative reviews and labels
    data_train = data['train']['pos'] + data['train']['neg']
    data_test = data['test']['pos'] + data['test']['neg']
    labels_train = labels['train']['pos'] + labels['train']['neg']
    labels_test = labels['test']['pos'] + labels['test']['neg']
    
    #Shuffle reviews and corresponding labels within training and test sets
    data_train, labels_train = shuffle(data_train, labels_train)
    data_test, labels_test = shuffle(data_test, labels_test)
    
    # Return a unified training data, test data, training labels, test labets
    return data_train, data_test, labels_train, labels_test

# %%
train_X, test_X, train_y, test_y = prepare_imdb_data(data, labels)
print("IMDb reviews (combined): train = {}, test = {}".format(len(train_X), len(test_X)))
# Out:
# IMDb reviews (combined): train = 25000, test = 25000

# %%
train_X[100]
# Out:
# "For all the hoopla, respect and recognition this film gets from Kung Fu historians, it still lacks glaringly in a couple critical areas: action and fight scenes. But I must say that the plot is probably the best and most original I've ever seen in a martial arts film. Five Deadly Venoms without a doubt is a must see, not only that, a movie you can watch again and again; but I also must say that after watching it you feel it could have been even better. It somehow leaves you wanting something, you want more. The producer Chang Cheh sets up the storyline beautifully for a potential masterpeice but doesn't follow through with giving us more of the action we want. The fighting styles in the movie really captures the viewer (Centipede,Snake,Scorpion,Lizard,Toad) and they are shown, but battles are noticeably short. The Toad and Snake styles are particularly intriguing and should have been showcased much, much more, in fact the Toad is killed off by the middle of the movie. Interestingly enough with this movie, the absence of constant action or fighting leads to development of a great plot, this is one of the few kung fu films where you are really interested in the storyline and care about the outcome. This movie has a dark and vicious tone to it and you are drawn into the vibe. Sinister weapons and torture tactics are used throughout the movie and adds to the movies feel. To start off the movie and to introduce the Poison Clan producer Chang Cheh takes us to a grimy dungeon. The ending fight scenes are certainly good but seem muffled and somehow you expected more. Still though this movie is one of Shaw Brothers best and is quite enjoyable. My overall impression of the movie would conclude with this: The styles the fighters used are merely shown to us and not showcased in detail, sad thing is , the director had the goods for something extraordinary right at his fingertips and didn't expand on it. I am left wondering what could have been with this movie, still one of the best though. 8 out of 10 on the scale."

# %% [markdown]
# ## Step 3: Processing the data
#
# Now that we have our training and testing datasets merged and ready to use, we need to start processing the raw data into something that will be useable by our machine learning algorithm. To begin with, we remove any html formatting that may appear in the reviews and perform some standard natural language processing in order to homogenize the data.

# %%
import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords
from nltk.stem.porter import *
stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
import re
from bs4 import BeautifulSoup

def review_to_words(review):
    text = BeautifulSoup(review, "html.parser").get_text() # Remove HTML tags
    text = re.sub(r"[^a-zA-Z0-9]", " ", text.lower()) # Convert to lower case
    words = text.split() # Split string into words
    words = [w for w in words if w not in stopwords.words("english")] # Remove stopwords
    words = [PorterStemmer().stem(w) for w in words] # stem
    
    return words

# %%
import pickle

cache_dir = os.path.join("../cache", "sentiment_analysis")  # where to store cache files
os.makedirs(cache_dir, exist_ok=True)  # ensure cache directory exists

def preprocess_data(data_train, data_test, labels_train, labels_test,
                    cache_dir=cache_dir, cache_file="preprocessed_data.pkl"):
    """Convert each review to words; read from cache if available."""

    # If cache_file is not None, try to read from it first
    cache_data = None
    if cache_file is not None:
        try:
            with open(os.path.join(cache_dir, cache_file), "rb") as f:
                cache_data = pickle.load(f)
            print("Read preprocessed data from cache file:", cache_file)
        except:
            pass  # unable to read from cache, but that's okay
    
    # If cache is missing, then do the heavy lifting
    if cache_data is None:
        # Preprocess training and test data to obtain words for each review
        #words_train = list(map(review_to_words, data_train))
        #words_test = list(map(review_to_words, data_test))
        words_train = [review_to_words(review) for review in data_train]
        words_test = [review_to_words(review) for review in data_test]
        
        # Write to cache file for future runs
        if cache_file is not None:
            cache_data = dict(words_train=words_train, words_test=words_test,
                              labels_train=labels_train, labels_test=labels_test)
            with open(os.path.join(cache_dir, cache_file), "wb") as f:
                pickle.dump(cache_data, f)
            print("Wrote preprocessed data to cache file:", cache_file)
    else:
        # Unpack data loaded from cache file
        words_train, words_test, labels_train, labels_test = (cache_data['words_train'],
                cache_data['words_test'], cache_data['labels_train'], cache_data['labels_test'])
    
    return words_train, words_test, labels_train, labels_test

# %%
# Preprocess data
train_X, test_X, train_y, test_y = preprocess_data(train_X, test_X, train_y, test_y)
# Out:
# Wrote preprocessed data to cache file: preprocessed_data.pkl

# %% [markdown]
# ### Extract Bag-of-Words features
#
# For the model we will be implementing, rather than using the reviews directly, we are going to transform each review into a Bag-of-Words feature representation. Keep in mind that 'in the wild' we will only have access to the training set so our transformer can only use the training set to construct a representation.

# %%
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.externals import joblib
# joblib is an enhanced version of pickle that is more efficient for storing NumPy arrays

def extract_BoW_features(words_train, words_test, vocabulary_size=5000,
                         cache_dir=cache_dir, cache_file="bow_features.pkl"):
    """Extract Bag-of-Words for a given set of documents, already preprocessed into words."""
    
    # If cache_file is not None, try to read from it first
    cache_data = None
    if cache_file is not None:
        try:
            with open(os.path.join(cache_dir, cache_file), "rb") as f:
                cache_data = joblib.load(f)
            print("Read features from cache file:", cache_file)
        except:
            pass  # unable to read from cache, but that's okay
    
    # If cache is missing, then do the heavy lifting
    if cache_data is None:
        # Fit a vectorizer to training documents and use it to transform them
        # NOTE: Training documents have already been preprocessed and tokenized into words;
        #       pass in dummy functions to skip those steps, e.g. preprocessor=lambda x: x
        vectorizer = CountVectorizer(max_features=vocabulary_size,
                preprocessor=lambda x: x, tokenizer=lambda x: x)  # already preprocessed
        features_train = vectorizer.fit_transform(words_train).toarray()

        # Apply the same vectorizer to transform the test documents (ignore unknown words)
        features_test = vectorizer.transform(words_test).toarray()
        
        # NOTE: Remember to convert the features using .toarray() for a compact representation
        
        # Write to cache file for future runs (store vocabulary as well)
        if cache_file is not None:
            vocabulary = vectorizer.vocabulary_
            cache_data = dict(features_train=features_train, features_test=features_test,
                             vocabulary=vocabulary)
            with open(os.path.join(cache_dir, cache_file), "wb") as f:
                joblib.dump(cache_data, f)
            print("Wrote features to cache file:", cache_file)
    else:
        # Unpack data loaded from cache file
        features_train, features_test, vocabulary = (cache_data['features_train'],
                cache_data['features_test'], cache_data['vocabulary'])
    
    # Return both the extracted features as well as the vocabulary
    return features_train, features_test, vocabulary

# %%
# Extract Bag of Words features for both training and test datasets
train_X, test_X, vocabulary = extract_BoW_features(train_X, test_X)
# Out:
# Wrote features to cache file: bow_features.pkl

# %% [markdown]
# ## Step 4: Classification using XGBoost
#
# Now that we have created the feature representation of our training (and testing) data, it is time to start setting up and using the XGBoost classifier provided by SageMaker.
#
# ### Writing the dataset
#
# The XGBoost classifier that we will be using requires the dataset to be written to a file and stored using Amazon S3. To do this, we will start by splitting the training dataset into two parts, the data we will train the model with and a validation set. Then, we will write those datasets to a file and upload the files to S3. In addition, we will write the test set input to a file and upload the file to S3. This is so that we can use SageMakers Batch Transform functionality to test our model once we've fit it.

# %%
import pandas as pd

val_X = pd.DataFrame(train_X[:10000])
train_X = pd.DataFrame(train_X[10000:])

val_y = pd.DataFrame(train_y[:10000])
train_y = pd.DataFrame(train_y[10000:])

test_y = pd.DataFrame(test_y)
test_X = pd.DataFrame(test_X)

# %% [markdown]
# The documentation for the XGBoost algorithm in SageMaker requires that the saved datasets should contain no headers or index and that for the training and validation data, the label should occur first for each sample.
#
# For more information about this and other algorithms, the SageMaker developer documentation can be found on __[Amazon's website.](https://docs.aws.amazon.com/sagemaker/latest/dg/)__

# %%
# First we make sure that the local directory in which we'd like to store the training and validation csv files exists.
data_dir = '../data/xgboost'
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

# %%
# First, save the test data to test.csv in the data_dir directory. Note that we do not save the associated ground truth
# labels, instead we will use them later to compare with our model output.

# pd.concat([test_y, test_X], axis=1).to_csv(os.path.join(data_dir, 'test.csv'), header=False, index=False)
pd.DataFrame(test_X).to_csv(os.path.join(data_dir, 'test.csv'), header=False, index=False)
pd.concat([val_y, val_X], axis=1).to_csv(os.path.join(data_dir, 'validation.csv'), header=False, index=False)
pd.concat([train_y, train_X], axis=1).to_csv(os.path.join(data_dir, 'train.csv'), header=False, index=False)

# %%
# To save a bit of memory we can set text_X, train_X, val_X, train_y and val_y to None.

train_X = val_X = train_y = val_y = None

# %% [markdown]
# ### Uploading Training / Validation files to S3
#
# Amazon's S3 service allows us to store files that can be access by both the built-in training models such as the XGBoost model we will be using as well as custom models such as the one we will see a little later.
#
# For this, and most other tasks we will be doing using SageMaker, there are two methods we could use. The first is to use the low level functionality of SageMaker which requires knowing each of the objects involved in the SageMaker environment. The second is to use the high level functionality in which certain choices have been made on the user's behalf. The low level approach benefits from allowing the user a great deal of flexibility while the high level approach makes development much quicker. For our purposes we will opt to use the high level approach although using the low-level approach is certainly an option.
#
# Recall the method `upload_data()` which is a member of object representing our current SageMaker session. What this method does is upload the data to the default bucket (which is created if it does not exist) into the path described by the key_prefix variable. To see this for yourself, once you have uploaded the data files, go to the S3 console and look to see where the files have been uploaded.
#
# For additional resources, see the __[SageMaker API documentation](http://sagemaker.readthedocs.io/en/latest/)__ and in addition the __[SageMaker Developer Guide.](https://docs.aws.amazon.com/sagemaker/latest/dg/)__

# %%
import sagemaker

session = sagemaker.Session() # Store the current SageMaker session

# S3 prefix (which folder will we use)
prefix = 'sentiment-xgboost'

test_location = session.upload_data(os.path.join(data_dir, 'test.csv'), key_prefix=prefix)
val_location = session.upload_data(os.path.join(data_dir, 'validation.csv'), key_prefix=prefix)
train_location = session.upload_data(os.path.join(data_dir, 'train.csv'), key_prefix=prefix)

# %% [markdown]
# ### (TODO) Creating a hypertuned XGBoost model
#
# Now that the data has been uploaded it is time to create the XGBoost model. As in the Boston Housing notebook, the first step is to create an estimator object which will be used as the *base* of your hyperparameter tuning job.

# %%
from sagemaker import get_execution_role

# Our current execution role is require when creating the model as the training
# and inference code will need to access the model artifacts.
role = get_execution_role()

# %%
# We need to retrieve the location of the container which is provided by Amazon for using XGBoost.
# As a matter of convenience, the training and inference code both use the same container.
from sagemaker.amazon.amazon_estimator import get_image_uri

container = get_image_uri(session.boto_region_name, 'xgboost')
# Out:
# WARNING:root:There is a more up to date SageMaker XGBoost image. To use the newer image, please set 'repo_version'='0.90-1'. For example:
# 	get_image_uri(region, 'xgboost', '0.90-1').

# %%
# TODO: Create a SageMaker estimator using the container location determined in the previous cell.
#       It is recommended that you use a single training instance of type ml.m4.xlarge. It is also
#       recommended that you use 's3://{}/{}/output'.format(session.default_bucket(), prefix) as the
#       output path.

xgb = None

# TODO: Set the XGBoost hyperparameters in the xgb object. Don't forget that in this case we have a binary
#       label so we should be using the 'binary:logistic' objective.

xgb = sagemaker.estimator.Estimator(container,
                                    role,
                                    train_instance_count=1,
                                    train_instance_type='ml.m4.xlarge',
                                    output_path='s3://{}/{}/output'.format(session.default_bucket(), prefix),
                                    sagemaker_session=session)

xgb.set_hyperparameters(max_depth=5,
                        eta=0.2,
                        gamma=4,
                        min_child_weight=6,
                        subsample=0.8,
                        silent=0,
                        objective='binary:logistic',
                        early_stopping_rounds=10,
                        num_round=500)

# %% [markdown]
# ### (TODO) Create the hyperparameter tuner
#
# Now that the base estimator has been set up we need to construct a hyperparameter tuner object which we will use to request SageMaker construct a hyperparameter tuning job.
#
# **Note:** Training a single sentiment analysis XGBoost model takes longer than training a Boston Housing XGBoost model so if you don't want the hyperparameter tuning job to take too long, make sure to not set the total number of models (jobs) too high.

# %%
# First, make sure to import the relevant objects used to construct the tuner
from sagemaker.tuner import IntegerParameter, ContinuousParameter, HyperparameterTuner

# TODO: Create the hyperparameter tuner object

xgb_hyperparameter_tuner = HyperparameterTuner(estimator = xgb,
                                               objective_metric_name = 'validation:rmse',
                                               objective_type = 'Minimize',
                                               max_jobs = 6,
                                               max_parallel_jobs = 3,
                                               hyperparameter_ranges = {
                                                    'max_depth': IntegerParameter(3, 12),
                                                    'eta'      : ContinuousParameter(0.05, 0.5),
                                                    'min_child_weight': IntegerParameter(2, 8),
                                                    'subsample': ContinuousParameter(0.5, 0.9),
                                                    'gamma': ContinuousParameter(0, 10),
                                               })

# %% [markdown]
# ### Fit the hyperparameter tuner
#
# Now that the hyperparameter tuner object has been constructed, it is time to fit the various models and find the best performing model.

# %%
s3_input_train = sagemaker.s3_input(s3_data=train_location, content_type='csv')
s3_input_validation = sagemaker.s3_input(s3_data=val_location, content_type='csv')

# %%
xgb_hyperparameter_tuner.fit({'train': s3_input_train, 'validation': s3_input_validation})

# %% [markdown]
# Remember that the tuning job is constructed and run in the background so if we want to see the progress of our training job we need to call the `wait()` method.

# %%
xgb_hyperparameter_tuner.wait()
# Out:
# .............................................................................................................................................................................................................................................................................................................!

# %% [markdown]
# ### (TODO) Testing the model
#
# Now that we've run our hyperparameter tuning job, it's time to see how well the best performing model actually performs. To do this we will use SageMaker's Batch Transform functionality. Batch Transform is a convenient way to perform inference on a large dataset in a way that is not realtime. That is, we don't necessarily need to use our model's results immediately and instead we can peform inference on a large number of samples. An example of this in industry might be peforming an end of month report. This method of inference can also be useful to us as it means to can perform inference on our entire test set.
#
# Remember that in order to create a transformer object to perform the batch transform job, we need a trained estimator object. We can do that using the `attach()` method, creating an estimator object which is attached to the best trained job.

# %%
# TODO: Create a new estimator object attached to the best training job found during hyperparameter tuning

xgb_attached = sagemaker.estimator.Estimator.attach(xgb_hyperparameter_tuner.best_training_job())
# Out:
# 2020-02-05 04:56:07 Starting - Preparing the instances for training
# 2020-02-05 04:56:07 Downloading - Downloading input data
# 2020-02-05 04:56:07 Training - Training image download completed. Training in progress.
# 2020-02-05 04:56:07 Uploading - Uploading generated training model
# 2020-02-05 04:56:07 Completed - Training job completedArguments: train
# [2020-02-05:04:46:59:INFO] Running standalone xgboost training.
# [2020-02-05:04:46:59:INFO] Setting up HPO optimized metric to be : rmse
# [2020-02-05:04:46:59:INFO] File size need to be processed in the node: 238.47mb. Available memory size in the node: 8519.11mb
# [2020-02-05:04:46:59:INFO] Determined delimiter of CSV input is ','
# [04:46:59] S3DistributionType set as FullyReplicated
# [04:47:01] 15000x5000 matrix with 75000000 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2020-02-05:04:47:01:INFO] Determined delimiter of CSV input is ','
# [04:47:01] S3DistributionType set as FullyReplicated
# [04:47:02] 10000x5000 matrix with 50000000 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [04:47:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 2 pruned nodes, max_depth=6
# [0]#011train-rmse:0.479865#011validation-rmse:0.480824
# Multiple eval metrics have been passed: 'validation-rmse' will be used for early stopping.
#
# Will train until validation-rmse hasn't improved in 10 rounds.
# [04:47:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 0 pruned nodes, max_depth=6
# [1]#011train-rmse:0.464929#011validation-rmse:0.46724
# [04:47:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [2]#011train-rmse:0.453324#011validation-rmse:0.455963
# [04:47:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 2 pruned nodes, max_depth=6
# [3]#011train-rmse:0.444483#011validation-rmse:0.448283
# [04:47:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 4 pruned nodes, max_depth=6
# [4]#011train-rmse:0.435954#011validation-rmse:0.440624
# [04:47:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [5]#011train-rmse:0.42935#011validation-rmse:0.435211
# [04:47:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [6]#011train-rmse:0.423228#011validation-rmse:0.429831
# [04:47:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 2 pruned nodes, max_depth=6
# [7]#011train-rmse:0.41751#011validation-rmse:0.424816
# [04:47:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 4 pruned nodes, max_depth=6
# [8]#011train-rmse:0.411986#011validation-rmse:0.420278
# [04:47:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [9]#011train-rmse:0.407004#011validation-rmse:0.415947
# [04:47:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=6
# [10]#011train-rmse:0.40259#011validation-rmse:0.412551
# [04:47:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 2 pruned nodes, max_depth=6
# [11]#011train-rmse:0.398708#011validation-rmse:0.409218
# [04:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 2 pruned nodes, max_depth=6
# [12]#011train-rmse:0.395164#011validation-rmse:0.406247
# [04:47:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 2 pruned nodes, max_depth=6
# [13]#011train-rmse:0.391756#011validation-rmse:0.403554
# [04:47:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 0 pruned nodes, max_depth=6
# [14]#011train-rmse:0.387707#011validation-rmse:0.400766
# [04:47:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 2 pruned nodes, max_depth=6
# [15]#011train-rmse:0.384724#011validation-rmse:0.398053
# [04:47:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=6
# [16]#011train-rmse:0.381771#011validation-rmse:0.395899
# [04:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 6 pruned nodes, max_depth=6
# [17]#011train-rmse:0.37894#011validation-rmse:0.393602
# [04:47:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 2 pruned nodes, max_depth=6
# [18]#011train-rmse:0.37626#011validation-rmse:0.391739
# [04:47:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 4 pruned nodes, max_depth=6
# [19]#011train-rmse:0.372978#011validation-rmse:0.389749
# [04:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 4 pruned nodes, max_depth=6
# [20]#011train-rmse:0.370138#011validation-rmse:0.387937
# [04:47:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 2 pruned nodes, max_depth=6
# [21]#011train-rmse:0.367679#011validation-rmse:0.386088
# [04:47:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 4 pruned nodes, max_depth=6
# [22]#011train-rmse:0.364814#011validation-rmse:0.384422
# [04:47:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=6
# [23]#011train-rmse:0.36217#011validation-rmse:0.382607
# [04:47:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 12 pruned nodes, max_depth=6
# [24]#011train-rmse:0.359579#011validation-rmse:0.380462
# [04:47:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 2 pruned nodes, max_depth=6
# [25]#011train-rmse:0.356897#011validation-rmse:0.378384
# [04:47:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=6
# [26]#011train-rmse:0.354899#011validation-rmse:0.376945
# [04:47:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 2 pruned nodes, max_depth=6
# [27]#011train-rmse:0.353298#011validation-rmse:0.37578
# [04:47:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 2 pruned nodes, max_depth=6
# [28]#011train-rmse:0.351525#011validation-rmse:0.374417
# [04:47:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 6 pruned nodes, max_depth=6
# [29]#011train-rmse:0.349904#011validation-rmse:0.373095
# [04:47:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [30]#011train-rmse:0.3479#011validation-rmse:0.371777
# [04:47:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 4 pruned nodes, max_depth=6
# [31]#011train-rmse:0.346195#011validation-rmse:0.370542
# [04:47:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [32]#011train-rmse:0.344316#011validation-rmse:0.369174
# [04:47:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 2 pruned nodes, max_depth=6
# [33]#011train-rmse:0.342695#011validation-rmse:0.36817
# [04:47:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 2 pruned nodes, max_depth=6
# [34]#011train-rmse:0.340808#011validation-rmse:0.366975
# [04:47:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [35]#011train-rmse:0.339118#011validation-rmse:0.365955
# [04:48:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 2 pruned nodes, max_depth=6
# [36]#011train-rmse:0.337449#011validation-rmse:0.364805
# [04:48:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [37]#011train-rmse:0.335853#011validation-rmse:0.363974
# [04:48:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 2 pruned nodes, max_depth=6
# [38]#011train-rmse:0.334259#011validation-rmse:0.362995
# [04:48:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 6 pruned nodes, max_depth=6
# [39]#011train-rmse:0.332412#011validation-rmse:0.362122
# [04:48:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 2 pruned nodes, max_depth=6
# [40]#011train-rmse:0.331172#011validation-rmse:0.361063
# [04:48:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 2 pruned nodes, max_depth=6
# [41]#011train-rmse:0.329904#011validation-rmse:0.360358
# [04:48:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 8 pruned nodes, max_depth=6
# [42]#011train-rmse:0.328122#011validation-rmse:0.359636
# [04:48:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [43]#011train-rmse:0.326502#011validation-rmse:0.358527
# [04:48:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 4 pruned nodes, max_depth=6
# [44]#011train-rmse:0.324887#011validation-rmse:0.357648
# [04:48:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 4 pruned nodes, max_depth=6
# [45]#011train-rmse:0.323776#011validation-rmse:0.356744
# [04:48:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 4 pruned nodes, max_depth=6
# [46]#011train-rmse:0.322717#011validation-rmse:0.356103
# [04:48:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 2 pruned nodes, max_depth=6
# [47]#011train-rmse:0.321692#011validation-rmse:0.355468
# [04:48:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [48]#011train-rmse:0.320672#011validation-rmse:0.354682
# [04:48:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 2 pruned nodes, max_depth=6
# [49]#011train-rmse:0.319157#011validation-rmse:0.35396
# [04:48:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 4 pruned nodes, max_depth=6
# [50]#011train-rmse:0.318141#011validation-rmse:0.353401
# [04:48:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 2 pruned nodes, max_depth=6
# [51]#011train-rmse:0.316959#011validation-rmse:0.352767
# [04:48:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [52]#011train-rmse:0.315929#011validation-rmse:0.352234
# [04:48:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 4 pruned nodes, max_depth=6
# [53]#011train-rmse:0.314862#011validation-rmse:0.351597
# [04:48:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 8 pruned nodes, max_depth=6
# [54]#011train-rmse:0.31397#011validation-rmse:0.35101
# [04:48:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 4 pruned nodes, max_depth=6
# [55]#011train-rmse:0.312982#011validation-rmse:0.350401
# [04:48:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 4 pruned nodes, max_depth=6
# [56]#011train-rmse:0.311797#011validation-rmse:0.349647
# [04:48:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 6 pruned nodes, max_depth=6
# [57]#011train-rmse:0.310696#011validation-rmse:0.349152
# [04:48:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [58]#011train-rmse:0.309875#011validation-rmse:0.348464
# [04:48:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [59]#011train-rmse:0.308705#011validation-rmse:0.347949
# [04:48:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 4 pruned nodes, max_depth=6
# [60]#011train-rmse:0.307304#011validation-rmse:0.347056
# [04:48:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 4 pruned nodes, max_depth=6
# [61]#011train-rmse:0.30623#011validation-rmse:0.346407
# [04:48:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [62]#011train-rmse:0.305289#011validation-rmse:0.345765
# [04:48:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 2 pruned nodes, max_depth=6
# [63]#011train-rmse:0.304305#011validation-rmse:0.345313
# [04:48:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 4 pruned nodes, max_depth=6
# [64]#011train-rmse:0.303336#011validation-rmse:0.344824
# [04:48:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 4 pruned nodes, max_depth=6
# [65]#011train-rmse:0.302287#011validation-rmse:0.344023
# [04:48:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 8 pruned nodes, max_depth=6
# [66]#011train-rmse:0.301479#011validation-rmse:0.343732
# [04:48:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 2 pruned nodes, max_depth=6
# [67]#011train-rmse:0.300466#011validation-rmse:0.343227
# [04:48:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 6 pruned nodes, max_depth=6
# [68]#011train-rmse:0.299698#011validation-rmse:0.342732
# [04:48:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [69]#011train-rmse:0.298739#011validation-rmse:0.342122
# [04:48:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 6 pruned nodes, max_depth=6
# [70]#011train-rmse:0.298016#011validation-rmse:0.341765
# [04:48:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 2 pruned nodes, max_depth=6
# [71]#011train-rmse:0.297259#011validation-rmse:0.341191
# [04:48:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 2 pruned nodes, max_depth=6
# [72]#011train-rmse:0.296174#011validation-rmse:0.340833
# [04:48:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 4 pruned nodes, max_depth=6
# [73]#011train-rmse:0.295363#011validation-rmse:0.340801
# [04:48:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 4 pruned nodes, max_depth=6
# [74]#011train-rmse:0.294393#011validation-rmse:0.340219
# [04:48:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 4 pruned nodes, max_depth=6
# [75]#011train-rmse:0.293542#011validation-rmse:0.339912
# [04:49:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 4 pruned nodes, max_depth=6
# [76]#011train-rmse:0.292954#011validation-rmse:0.339421
# [04:49:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 4 pruned nodes, max_depth=6
# [77]#011train-rmse:0.291787#011validation-rmse:0.339057
# [04:49:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 2 pruned nodes, max_depth=6
# [78]#011train-rmse:0.291343#011validation-rmse:0.33882
# [04:49:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 2 pruned nodes, max_depth=6
# [79]#011train-rmse:0.290688#011validation-rmse:0.338558
# [04:49:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 10 pruned nodes, max_depth=6
# [80]#011train-rmse:0.290016#011validation-rmse:0.338281
# [04:49:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 4 pruned nodes, max_depth=6
# [81]#011train-rmse:0.288633#011validation-rmse:0.337744
# [04:49:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [82]#011train-rmse:0.287984#011validation-rmse:0.337314
# [04:49:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 4 pruned nodes, max_depth=6
# [83]#011train-rmse:0.287296#011validation-rmse:0.336964
# [04:49:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 2 pruned nodes, max_depth=6
# [84]#011train-rmse:0.286761#011validation-rmse:0.336563
# [04:49:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 4 pruned nodes, max_depth=6
# [85]#011train-rmse:0.286006#011validation-rmse:0.336147
# [04:49:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [86]#011train-rmse:0.285208#011validation-rmse:0.335877
# [04:49:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [87]#011train-rmse:0.284469#011validation-rmse:0.335383
# [04:49:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 2 pruned nodes, max_depth=6
# [88]#011train-rmse:0.283689#011validation-rmse:0.334956
# [04:49:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 2 pruned nodes, max_depth=6
# [89]#011train-rmse:0.282946#011validation-rmse:0.334549
# [04:49:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 2 pruned nodes, max_depth=6
# [90]#011train-rmse:0.282235#011validation-rmse:0.33419
# [04:49:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 2 pruned nodes, max_depth=6
# [91]#011train-rmse:0.281753#011validation-rmse:0.333979
# [04:49:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 4 pruned nodes, max_depth=6
# [92]#011train-rmse:0.281213#011validation-rmse:0.333636
# [04:49:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 2 pruned nodes, max_depth=6
# [93]#011train-rmse:0.280409#011validation-rmse:0.333454
# [04:49:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [94]#011train-rmse:0.279927#011validation-rmse:0.333232
# [04:49:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 2 pruned nodes, max_depth=6
# [95]#011train-rmse:0.279375#011validation-rmse:0.332893
# [04:49:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 2 pruned nodes, max_depth=6
# [96]#011train-rmse:0.278789#011validation-rmse:0.332676
# [04:49:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 8 pruned nodes, max_depth=6
# [97]#011train-rmse:0.278265#011validation-rmse:0.332434
# [04:49:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 8 pruned nodes, max_depth=6
# [98]#011train-rmse:0.277793#011validation-rmse:0.332119
# [04:49:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 4 pruned nodes, max_depth=6
# [99]#011train-rmse:0.277253#011validation-rmse:0.331885
# [04:49:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 2 pruned nodes, max_depth=6
# [100]#011train-rmse:0.276443#011validation-rmse:0.331693
# [04:49:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 6 pruned nodes, max_depth=6
# [101]#011train-rmse:0.27576#011validation-rmse:0.331436
# [04:49:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [102]#011train-rmse:0.275144#011validation-rmse:0.331091
# [04:49:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 2 pruned nodes, max_depth=6
# [103]#011train-rmse:0.274714#011validation-rmse:0.330939
# [04:49:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 4 pruned nodes, max_depth=6
# [104]#011train-rmse:0.274158#011validation-rmse:0.330839
# [04:49:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 4 pruned nodes, max_depth=6
# [105]#011train-rmse:0.273689#011validation-rmse:0.330583
# [04:49:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 6 pruned nodes, max_depth=6
# [106]#011train-rmse:0.273288#011validation-rmse:0.330202
# [04:49:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 6 pruned nodes, max_depth=6
# [107]#011train-rmse:0.272723#011validation-rmse:0.330033
# [04:49:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 2 pruned nodes, max_depth=6
# [108]#011train-rmse:0.27214#011validation-rmse:0.329734
# [04:49:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 4 pruned nodes, max_depth=6
# [109]#011train-rmse:0.271589#011validation-rmse:0.329356
# [04:49:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 2 pruned nodes, max_depth=6
# [110]#011train-rmse:0.271187#011validation-rmse:0.329308
# [04:49:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 6 pruned nodes, max_depth=6
# [111]#011train-rmse:0.270234#011validation-rmse:0.329317
# [04:49:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [112]#011train-rmse:0.269553#011validation-rmse:0.328883
# [04:49:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 6 pruned nodes, max_depth=6
# [113]#011train-rmse:0.268892#011validation-rmse:0.328641
# [04:49:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [114]#011train-rmse:0.268307#011validation-rmse:0.328315
# [04:49:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 4 pruned nodes, max_depth=6
# [115]#011train-rmse:0.267879#011validation-rmse:0.328048
# [04:50:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 6 pruned nodes, max_depth=6
# [116]#011train-rmse:0.267312#011validation-rmse:0.327871
# [04:50:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [117]#011train-rmse:0.266763#011validation-rmse:0.327651
# [04:50:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 4 pruned nodes, max_depth=6
# [118]#011train-rmse:0.266396#011validation-rmse:0.327714
# [04:50:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 2 pruned nodes, max_depth=6
# [119]#011train-rmse:0.265988#011validation-rmse:0.327439
# [04:50:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=6
# [120]#011train-rmse:0.264892#011validation-rmse:0.327422
# [04:50:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 10 pruned nodes, max_depth=6
# [121]#011train-rmse:0.26426#011validation-rmse:0.327153
# [04:50:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [122]#011train-rmse:0.263956#011validation-rmse:0.327139
# [04:50:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 4 pruned nodes, max_depth=6
# [123]#011train-rmse:0.263543#011validation-rmse:0.327051
# [04:50:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 2 pruned nodes, max_depth=6
# [124]#011train-rmse:0.263226#011validation-rmse:0.32689
# [04:50:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 2 pruned nodes, max_depth=6
# [125]#011train-rmse:0.262645#011validation-rmse:0.326635
# [04:50:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 2 pruned nodes, max_depth=6
# [126]#011train-rmse:0.262151#011validation-rmse:0.326282
# [04:50:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 6 pruned nodes, max_depth=6
# [127]#011train-rmse:0.261514#011validation-rmse:0.32611
# [04:50:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 2 pruned nodes, max_depth=6
# [128]#011train-rmse:0.261121#011validation-rmse:0.326014
# [04:50:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 4 pruned nodes, max_depth=6
# [129]#011train-rmse:0.26061#011validation-rmse:0.325821
# [04:50:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 2 pruned nodes, max_depth=6
# [130]#011train-rmse:0.259864#011validation-rmse:0.32558
# [04:50:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 4 pruned nodes, max_depth=6
# [131]#011train-rmse:0.259219#011validation-rmse:0.325547
# [04:50:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 2 pruned nodes, max_depth=6
# [132]#011train-rmse:0.258603#011validation-rmse:0.325464
# [04:50:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [133]#011train-rmse:0.257981#011validation-rmse:0.325267
# [04:50:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 2 pruned nodes, max_depth=6
# [134]#011train-rmse:0.257617#011validation-rmse:0.325071
# [04:50:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 4 pruned nodes, max_depth=6
# [135]#011train-rmse:0.257309#011validation-rmse:0.324952
# [04:50:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 4 pruned nodes, max_depth=6
# [136]#011train-rmse:0.256732#011validation-rmse:0.324809
# [04:50:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 2 pruned nodes, max_depth=6
# [137]#011train-rmse:0.256219#011validation-rmse:0.324617
# [04:50:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [138]#011train-rmse:0.255761#011validation-rmse:0.324414
# [04:50:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 6 pruned nodes, max_depth=6
# [139]#011train-rmse:0.255367#011validation-rmse:0.32433
# [04:50:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [140]#011train-rmse:0.255041#011validation-rmse:0.324081
# [04:50:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 4 pruned nodes, max_depth=6
# [141]#011train-rmse:0.254381#011validation-rmse:0.32383
# [04:50:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [142]#011train-rmse:0.253775#011validation-rmse:0.323704
# [04:50:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 4 pruned nodes, max_depth=6
# [143]#011train-rmse:0.25339#011validation-rmse:0.323501
# [04:50:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 2 pruned nodes, max_depth=6
# [144]#011train-rmse:0.252926#011validation-rmse:0.323419
# [04:50:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 2 pruned nodes, max_depth=6
# [145]#011train-rmse:0.252672#011validation-rmse:0.323222
# [04:50:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [146]#011train-rmse:0.252243#011validation-rmse:0.322945
# [04:50:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 4 pruned nodes, max_depth=6
# [147]#011train-rmse:0.251678#011validation-rmse:0.322937
# [04:50:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 2 pruned nodes, max_depth=6
# [148]#011train-rmse:0.251323#011validation-rmse:0.322811
# [04:50:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [149]#011train-rmse:0.250746#011validation-rmse:0.322684
# [04:50:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 2 pruned nodes, max_depth=6
# [150]#011train-rmse:0.250287#011validation-rmse:0.322627
# [04:50:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [151]#011train-rmse:0.249833#011validation-rmse:0.322521
# [04:50:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 4 pruned nodes, max_depth=6
# [152]#011train-rmse:0.249459#011validation-rmse:0.322313
# [04:50:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [153]#011train-rmse:0.249153#011validation-rmse:0.322242
# [04:50:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 2 pruned nodes, max_depth=6
# [154]#011train-rmse:0.248358#011validation-rmse:0.322128
# [04:50:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 4 pruned nodes, max_depth=6
# [155]#011train-rmse:0.248105#011validation-rmse:0.321964
# [04:51:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [156]#011train-rmse:0.247635#011validation-rmse:0.321863
# [04:51:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 2 pruned nodes, max_depth=6
# [157]#011train-rmse:0.247204#011validation-rmse:0.321854
# [04:51:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 4 pruned nodes, max_depth=6
# [158]#011train-rmse:0.246777#011validation-rmse:0.32167
# [04:51:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [159]#011train-rmse:0.246319#011validation-rmse:0.321563
# [04:51:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 2 pruned nodes, max_depth=6
# [160]#011train-rmse:0.245927#011validation-rmse:0.321313
# [04:51:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [161]#011train-rmse:0.24555#011validation-rmse:0.321054
# [04:51:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 2 pruned nodes, max_depth=6
# [162]#011train-rmse:0.24519#011validation-rmse:0.321063
# [04:51:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 4 pruned nodes, max_depth=6
# [163]#011train-rmse:0.244849#011validation-rmse:0.320907
# [04:51:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 2 pruned nodes, max_depth=6
# [164]#011train-rmse:0.244534#011validation-rmse:0.320864
# [04:51:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [165]#011train-rmse:0.243919#011validation-rmse:0.320602
# [04:51:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 4 pruned nodes, max_depth=6
# [166]#011train-rmse:0.24357#011validation-rmse:0.32054
# [04:51:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 2 pruned nodes, max_depth=6
# [167]#011train-rmse:0.243317#011validation-rmse:0.320478
# [04:51:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 2 pruned nodes, max_depth=6
# [168]#011train-rmse:0.242841#011validation-rmse:0.320369
# [04:51:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 6 pruned nodes, max_depth=6
# [169]#011train-rmse:0.242517#011validation-rmse:0.320161
# [04:51:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 6 pruned nodes, max_depth=6
# [170]#011train-rmse:0.242118#011validation-rmse:0.320129
# [04:51:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 2 pruned nodes, max_depth=6
# [171]#011train-rmse:0.241792#011validation-rmse:0.320124
# [04:51:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 4 pruned nodes, max_depth=6
# [172]#011train-rmse:0.241199#011validation-rmse:0.31999
# [04:51:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 2 pruned nodes, max_depth=6
# [173]#011train-rmse:0.240887#011validation-rmse:0.319852
# [04:51:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [174]#011train-rmse:0.240595#011validation-rmse:0.319723
# [04:51:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [175]#011train-rmse:0.240231#011validation-rmse:0.319686
# [04:51:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 2 pruned nodes, max_depth=6
# [176]#011train-rmse:0.239961#011validation-rmse:0.319519
# [04:51:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 6 pruned nodes, max_depth=6
# [177]#011train-rmse:0.239656#011validation-rmse:0.319336
# [04:51:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 4 pruned nodes, max_depth=6
# [178]#011train-rmse:0.239289#011validation-rmse:0.319158
# [04:51:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 2 pruned nodes, max_depth=6
# [179]#011train-rmse:0.23888#011validation-rmse:0.31906
# [04:51:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 6 pruned nodes, max_depth=6
# [180]#011train-rmse:0.238209#011validation-rmse:0.318858
# [04:51:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 2 pruned nodes, max_depth=6
# [181]#011train-rmse:0.237772#011validation-rmse:0.318842
# [04:51:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 2 pruned nodes, max_depth=6
# [182]#011train-rmse:0.237301#011validation-rmse:0.318834
# [04:51:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 4 pruned nodes, max_depth=6
# [183]#011train-rmse:0.236795#011validation-rmse:0.318725
# [04:51:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 6 pruned nodes, max_depth=6
# [184]#011train-rmse:0.236377#011validation-rmse:0.318621
# [04:51:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=6
# [185]#011train-rmse:0.23617#011validation-rmse:0.318461
# [04:51:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 4 pruned nodes, max_depth=6
# [186]#011train-rmse:0.23568#011validation-rmse:0.318367
# [04:51:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 2 pruned nodes, max_depth=6
# [187]#011train-rmse:0.235375#011validation-rmse:0.318179
# [04:51:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 2 pruned nodes, max_depth=6
# [188]#011train-rmse:0.235101#011validation-rmse:0.318065
# [04:51:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 2 pruned nodes, max_depth=6
# [189]#011train-rmse:0.234848#011validation-rmse:0.318028
# [04:51:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 2 pruned nodes, max_depth=6
# [190]#011train-rmse:0.234638#011validation-rmse:0.317872
# [04:51:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 2 pruned nodes, max_depth=6
# [191]#011train-rmse:0.234429#011validation-rmse:0.317628
# [04:51:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 4 pruned nodes, max_depth=6
# [192]#011train-rmse:0.233775#011validation-rmse:0.317501
# [04:51:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [193]#011train-rmse:0.233357#011validation-rmse:0.317254
# [04:51:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [194]#011train-rmse:0.232992#011validation-rmse:0.317303
# [04:51:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 2 pruned nodes, max_depth=6
# [195]#011train-rmse:0.232606#011validation-rmse:0.317294
# [04:51:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 2 pruned nodes, max_depth=6
# [196]#011train-rmse:0.232224#011validation-rmse:0.317186
# [04:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 6 pruned nodes, max_depth=6
# [197]#011train-rmse:0.231821#011validation-rmse:0.317256
# [04:52:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 2 pruned nodes, max_depth=6
# [198]#011train-rmse:0.231563#011validation-rmse:0.317206
# [04:52:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [199]#011train-rmse:0.231107#011validation-rmse:0.317176
# [04:52:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 4 pruned nodes, max_depth=6
# [200]#011train-rmse:0.230589#011validation-rmse:0.31702
# [04:52:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [201]#011train-rmse:0.230319#011validation-rmse:0.316845
# [04:52:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 4 pruned nodes, max_depth=6
# [202]#011train-rmse:0.230093#011validation-rmse:0.316757
# [04:52:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 2 pruned nodes, max_depth=6
# [203]#011train-rmse:0.229864#011validation-rmse:0.316733
# [04:52:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [204]#011train-rmse:0.229509#011validation-rmse:0.31661
# [04:52:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 4 pruned nodes, max_depth=6
# [205]#011train-rmse:0.229246#011validation-rmse:0.316428
# [04:52:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [206]#011train-rmse:0.228941#011validation-rmse:0.316419
# [04:52:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [207]#011train-rmse:0.22862#011validation-rmse:0.316331
# [04:52:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [208]#011train-rmse:0.22836#011validation-rmse:0.316283
# [04:52:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 4 pruned nodes, max_depth=6
# [209]#011train-rmse:0.228163#011validation-rmse:0.316268
# [04:52:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 4 pruned nodes, max_depth=6
# [210]#011train-rmse:0.227867#011validation-rmse:0.316082
# [04:52:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 2 pruned nodes, max_depth=6
# [211]#011train-rmse:0.227358#011validation-rmse:0.315853
# [04:52:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 2 pruned nodes, max_depth=6
# [212]#011train-rmse:0.22699#011validation-rmse:0.315904
# [04:52:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [213]#011train-rmse:0.226468#011validation-rmse:0.315821
# [04:52:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 4 pruned nodes, max_depth=6
# [214]#011train-rmse:0.226094#011validation-rmse:0.315701
# [04:52:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [215]#011train-rmse:0.225865#011validation-rmse:0.315575
# [04:52:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 2 pruned nodes, max_depth=6
# [216]#011train-rmse:0.225481#011validation-rmse:0.315485
# [04:52:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 4 pruned nodes, max_depth=6
# [217]#011train-rmse:0.225134#011validation-rmse:0.315365
# [04:52:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 4 pruned nodes, max_depth=6
# [218]#011train-rmse:0.224956#011validation-rmse:0.315296
# [04:52:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 6 pruned nodes, max_depth=6
# [219]#011train-rmse:0.224786#011validation-rmse:0.315248
# [04:52:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 4 pruned nodes, max_depth=6
# [220]#011train-rmse:0.224664#011validation-rmse:0.315113
# [04:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [221]#011train-rmse:0.224456#011validation-rmse:0.315167
# [04:52:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 6 pruned nodes, max_depth=6
# [222]#011train-rmse:0.224282#011validation-rmse:0.315053
# [04:52:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 2 pruned nodes, max_depth=6
# [223]#011train-rmse:0.223997#011validation-rmse:0.315035
# [04:52:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 2 pruned nodes, max_depth=6
# [224]#011train-rmse:0.223767#011validation-rmse:0.315057
# [04:52:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 4 pruned nodes, max_depth=6
# [225]#011train-rmse:0.22356#011validation-rmse:0.315035
# [04:52:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 2 pruned nodes, max_depth=6
# [226]#011train-rmse:0.223283#011validation-rmse:0.315068
# [04:52:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 2 pruned nodes, max_depth=6
# [227]#011train-rmse:0.223074#011validation-rmse:0.314924
# [04:52:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 2 pruned nodes, max_depth=6
# [228]#011train-rmse:0.222782#011validation-rmse:0.314851
# [04:52:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 2 pruned nodes, max_depth=6
# [229]#011train-rmse:0.222407#011validation-rmse:0.314711
# [04:52:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 8 pruned nodes, max_depth=6
# [230]#011train-rmse:0.222189#011validation-rmse:0.314599
# [04:52:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 2 pruned nodes, max_depth=6
# [231]#011train-rmse:0.221936#011validation-rmse:0.314548
# [04:52:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [232]#011train-rmse:0.221636#011validation-rmse:0.314522
# [04:52:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 4 pruned nodes, max_depth=6
# [233]#011train-rmse:0.221394#011validation-rmse:0.314543
# [04:52:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 4 pruned nodes, max_depth=6
# [234]#011train-rmse:0.221179#011validation-rmse:0.314465
# [04:52:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 4 pruned nodes, max_depth=6
# [235]#011train-rmse:0.220924#011validation-rmse:0.314512
# [04:52:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 2 pruned nodes, max_depth=6
# [236]#011train-rmse:0.220699#011validation-rmse:0.314449
# [04:53:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 6 pruned nodes, max_depth=6
# [237]#011train-rmse:0.220494#011validation-rmse:0.314377
# [04:53:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 8 pruned nodes, max_depth=6
# [238]#011train-rmse:0.220247#011validation-rmse:0.314417
# [04:53:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 10 pruned nodes, max_depth=6
# [239]#011train-rmse:0.219976#011validation-rmse:0.314379
# [04:53:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [240]#011train-rmse:0.219806#011validation-rmse:0.31431
# [04:53:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 2 pruned nodes, max_depth=6
# [241]#011train-rmse:0.219539#011validation-rmse:0.314243
# [04:53:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [242]#011train-rmse:0.219057#011validation-rmse:0.314152
# [04:53:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 2 pruned nodes, max_depth=6
# [243]#011train-rmse:0.21874#011validation-rmse:0.314105
# [04:53:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [244]#011train-rmse:0.218549#011validation-rmse:0.314029
# [04:53:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 4 pruned nodes, max_depth=6
# [245]#011train-rmse:0.218326#011validation-rmse:0.313892
# [04:53:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 4 pruned nodes, max_depth=6
# [246]#011train-rmse:0.217867#011validation-rmse:0.31375
# [04:53:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 6 pruned nodes, max_depth=6
# [247]#011train-rmse:0.217454#011validation-rmse:0.313758
# [04:53:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 4 pruned nodes, max_depth=6
# [248]#011train-rmse:0.217211#011validation-rmse:0.313704
# [04:53:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 4 pruned nodes, max_depth=6
# [249]#011train-rmse:0.21697#011validation-rmse:0.313637
# [04:53:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 12 pruned nodes, max_depth=6
# [250]#011train-rmse:0.216516#011validation-rmse:0.313593
# [04:53:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [251]#011train-rmse:0.216132#011validation-rmse:0.313576
# [04:53:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 2 pruned nodes, max_depth=6
# [252]#011train-rmse:0.215974#011validation-rmse:0.313448
# [04:53:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 2 pruned nodes, max_depth=6
# [253]#011train-rmse:0.215459#011validation-rmse:0.313461
# [04:53:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 6 pruned nodes, max_depth=6
# [254]#011train-rmse:0.215147#011validation-rmse:0.313283
# [04:53:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 2 pruned nodes, max_depth=6
# [255]#011train-rmse:0.214956#011validation-rmse:0.313241
# [04:53:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [256]#011train-rmse:0.21474#011validation-rmse:0.313193
# [04:53:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [257]#011train-rmse:0.21433#011validation-rmse:0.313164
# [04:53:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 2 pruned nodes, max_depth=6
# [258]#011train-rmse:0.214201#011validation-rmse:0.313112
# [04:53:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 2 pruned nodes, max_depth=6
# [259]#011train-rmse:0.213855#011validation-rmse:0.312979
# [04:53:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 8 pruned nodes, max_depth=6
# [260]#011train-rmse:0.213597#011validation-rmse:0.312933
# [04:53:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [261]#011train-rmse:0.213375#011validation-rmse:0.312843
# [04:53:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [262]#011train-rmse:0.213183#011validation-rmse:0.312824
# [04:53:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 2 pruned nodes, max_depth=6
# [263]#011train-rmse:0.213046#011validation-rmse:0.312817
# [04:53:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 4 pruned nodes, max_depth=6
# [264]#011train-rmse:0.212781#011validation-rmse:0.312765
# [04:53:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 4 pruned nodes, max_depth=6
# [265]#011train-rmse:0.212589#011validation-rmse:0.312674
# [04:53:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 8 pruned nodes, max_depth=6
# [266]#011train-rmse:0.21222#011validation-rmse:0.312598
# [04:53:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 4 pruned nodes, max_depth=6
# [267]#011train-rmse:0.21206#011validation-rmse:0.312516
# [04:53:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [268]#011train-rmse:0.211884#011validation-rmse:0.312423
# [04:53:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 2 pruned nodes, max_depth=6
# [269]#011train-rmse:0.211731#011validation-rmse:0.312427
# [04:53:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [270]#011train-rmse:0.211476#011validation-rmse:0.312444
# [04:53:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [271]#011train-rmse:0.211332#011validation-rmse:0.31234
# [04:53:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 2 pruned nodes, max_depth=6
# [272]#011train-rmse:0.211059#011validation-rmse:0.312215
# [04:53:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [273]#011train-rmse:0.210713#011validation-rmse:0.312035
# [04:53:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 2 pruned nodes, max_depth=6
# [274]#011train-rmse:0.210499#011validation-rmse:0.311904
# [04:53:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 4 pruned nodes, max_depth=6
# [275]#011train-rmse:0.210273#011validation-rmse:0.311827
# [04:53:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 4 pruned nodes, max_depth=6
# [276]#011train-rmse:0.210015#011validation-rmse:0.311871
# [04:54:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 2 pruned nodes, max_depth=6
# [277]#011train-rmse:0.209738#011validation-rmse:0.311843
# [04:54:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 2 pruned nodes, max_depth=6
# [278]#011train-rmse:0.20947#011validation-rmse:0.311849
# [04:54:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [279]#011train-rmse:0.209257#011validation-rmse:0.311815
# [04:54:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 2 pruned nodes, max_depth=6
# [280]#011train-rmse:0.208988#011validation-rmse:0.311824
# [04:54:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 2 pruned nodes, max_depth=6
# [281]#011train-rmse:0.208669#011validation-rmse:0.311635
# [04:54:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 2 pruned nodes, max_depth=6
# [282]#011train-rmse:0.208215#011validation-rmse:0.31176
# [04:54:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 4 pruned nodes, max_depth=6
# [283]#011train-rmse:0.207854#011validation-rmse:0.311793
# [04:54:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 4 pruned nodes, max_depth=6
# [284]#011train-rmse:0.207471#011validation-rmse:0.311711
# [04:54:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 8 pruned nodes, max_depth=6
# [285]#011train-rmse:0.20733#011validation-rmse:0.311737
# [04:54:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 4 pruned nodes, max_depth=6
# [286]#011train-rmse:0.207119#011validation-rmse:0.311683
# [04:54:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=6
# [287]#011train-rmse:0.206991#011validation-rmse:0.31163
# [04:54:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=6
# [288]#011train-rmse:0.206887#011validation-rmse:0.311616
# [04:54:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 6 pruned nodes, max_depth=6
# [289]#011train-rmse:0.206629#011validation-rmse:0.31156
# [04:54:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 2 pruned nodes, max_depth=6
# [290]#011train-rmse:0.206258#011validation-rmse:0.31161
# [04:54:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 6 pruned nodes, max_depth=6
# [291]#011train-rmse:0.206#011validation-rmse:0.311672
# [04:54:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [292]#011train-rmse:0.205874#011validation-rmse:0.311583
# [04:54:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 6 pruned nodes, max_depth=6
# [293]#011train-rmse:0.205709#011validation-rmse:0.311555
# [04:54:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 6 pruned nodes, max_depth=6
# [294]#011train-rmse:0.205583#011validation-rmse:0.311431
# [04:54:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 4 pruned nodes, max_depth=6
# [295]#011train-rmse:0.205245#011validation-rmse:0.311323
# [04:54:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 2 pruned nodes, max_depth=6
# [296]#011train-rmse:0.205059#011validation-rmse:0.31126
# [04:54:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 2 pruned nodes, max_depth=6
# [297]#011train-rmse:0.204757#011validation-rmse:0.311333
# [04:54:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 2 pruned nodes, max_depth=6
# [298]#011train-rmse:0.204595#011validation-rmse:0.311298
# [04:54:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [299]#011train-rmse:0.204379#011validation-rmse:0.311282
# [04:54:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 4 pruned nodes, max_depth=6
# [300]#011train-rmse:0.20412#011validation-rmse:0.311228
# [04:54:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 6 pruned nodes, max_depth=6
# [301]#011train-rmse:0.203828#011validation-rmse:0.311271
# [04:54:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [302]#011train-rmse:0.203343#011validation-rmse:0.311196
# [04:54:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 10 pruned nodes, max_depth=6
# [303]#011train-rmse:0.202872#011validation-rmse:0.311106
# [04:54:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 2 pruned nodes, max_depth=6
# [304]#011train-rmse:0.202706#011validation-rmse:0.310984
# [04:54:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [305]#011train-rmse:0.202513#011validation-rmse:0.31092
# [04:54:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 2 pruned nodes, max_depth=6
# [306]#011train-rmse:0.202131#011validation-rmse:0.310748
# [04:54:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 4 pruned nodes, max_depth=6
# [307]#011train-rmse:0.202009#011validation-rmse:0.310713
# [04:54:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 2 pruned nodes, max_depth=6
# [308]#011train-rmse:0.201444#011validation-rmse:0.310784
# [04:54:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [309]#011train-rmse:0.201201#011validation-rmse:0.310677
# [04:54:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 6 pruned nodes, max_depth=6
# [310]#011train-rmse:0.200741#011validation-rmse:0.310601
# [04:54:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=6
# [311]#011train-rmse:0.20057#011validation-rmse:0.310503
# [04:54:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 2 pruned nodes, max_depth=6
# [312]#011train-rmse:0.20022#011validation-rmse:0.310412
# [04:54:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 2 pruned nodes, max_depth=6
# [313]#011train-rmse:0.199776#011validation-rmse:0.310271
# [04:54:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 6 pruned nodes, max_depth=6
# [314]#011train-rmse:0.199435#011validation-rmse:0.310327
# [04:54:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 4 pruned nodes, max_depth=6
# [315]#011train-rmse:0.199268#011validation-rmse:0.31021
# [04:54:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 2 pruned nodes, max_depth=6
# [316]#011train-rmse:0.199057#011validation-rmse:0.310017
# [04:55:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 6 pruned nodes, max_depth=6
# [317]#011train-rmse:0.198983#011validation-rmse:0.309969
# [04:55:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 2 pruned nodes, max_depth=6
# [318]#011train-rmse:0.198809#011validation-rmse:0.309944
# [04:55:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 4 pruned nodes, max_depth=6
# [319]#011train-rmse:0.198333#011validation-rmse:0.30982
# [04:55:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 2 pruned nodes, max_depth=6
# [320]#011train-rmse:0.198124#011validation-rmse:0.309802
# [04:55:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 4 pruned nodes, max_depth=6
# [321]#011train-rmse:0.197904#011validation-rmse:0.309851
# [04:55:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 4 pruned nodes, max_depth=6
# [322]#011train-rmse:0.197643#011validation-rmse:0.309799
# [04:55:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 4 pruned nodes, max_depth=6
# [323]#011train-rmse:0.197392#011validation-rmse:0.309919
# [04:55:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 2 pruned nodes, max_depth=6
# [324]#011train-rmse:0.197181#011validation-rmse:0.309888
# [04:55:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 2 pruned nodes, max_depth=6
# [325]#011train-rmse:0.196992#011validation-rmse:0.30982
# [04:55:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 8 pruned nodes, max_depth=6
# [326]#011train-rmse:0.196767#011validation-rmse:0.309772
# [04:55:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [327]#011train-rmse:0.196568#011validation-rmse:0.309771
# [04:55:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 4 pruned nodes, max_depth=6
# [328]#011train-rmse:0.196461#011validation-rmse:0.30974
# [04:55:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 2 pruned nodes, max_depth=6
# [329]#011train-rmse:0.196332#011validation-rmse:0.309629
# [04:55:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 6 pruned nodes, max_depth=6
# [330]#011train-rmse:0.196185#011validation-rmse:0.309599
# [04:55:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 2 pruned nodes, max_depth=6
# [331]#011train-rmse:0.196029#011validation-rmse:0.309614
# [04:55:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 2 pruned nodes, max_depth=6
# [332]#011train-rmse:0.195851#011validation-rmse:0.309612
# [04:55:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 2 pruned nodes, max_depth=6
# [333]#011train-rmse:0.195706#011validation-rmse:0.309569
# [04:55:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 4 pruned nodes, max_depth=6
# [334]#011train-rmse:0.195593#011validation-rmse:0.309509
# [04:55:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 4 pruned nodes, max_depth=6
# [335]#011train-rmse:0.195308#011validation-rmse:0.309432
# [04:55:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [336]#011train-rmse:0.195122#011validation-rmse:0.309533
# [04:55:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 2 pruned nodes, max_depth=6
# [337]#011train-rmse:0.194938#011validation-rmse:0.309445
# [04:55:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 10 pruned nodes, max_depth=6
# [338]#011train-rmse:0.19479#011validation-rmse:0.309369
# [04:55:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 2 pruned nodes, max_depth=6
# [339]#011train-rmse:0.194571#011validation-rmse:0.309272
# [04:55:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 2 pruned nodes, max_depth=6
# [340]#011train-rmse:0.19434#011validation-rmse:0.309301
# [04:55:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [341]#011train-rmse:0.1941#011validation-rmse:0.309286
# [04:55:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=6
# [342]#011train-rmse:0.193984#011validation-rmse:0.30929
# [04:55:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=6
# [343]#011train-rmse:0.193869#011validation-rmse:0.309267
# [04:55:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 2 pruned nodes, max_depth=6
# [344]#011train-rmse:0.19357#011validation-rmse:0.309124
# [04:55:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 10 pruned nodes, max_depth=6
# [345]#011train-rmse:0.193412#011validation-rmse:0.309021
# [04:55:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 4 pruned nodes, max_depth=6
# [346]#011train-rmse:0.193189#011validation-rmse:0.309036
# [04:55:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 2 pruned nodes, max_depth=6
# [347]#011train-rmse:0.193008#011validation-rmse:0.309065
# [04:55:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [348]#011train-rmse:0.192871#011validation-rmse:0.309157
# [04:55:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=6
# [349]#011train-rmse:0.192779#011validation-rmse:0.309206
# [04:55:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=6
# [350]#011train-rmse:0.192656#011validation-rmse:0.309118
# [04:55:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 2 pruned nodes, max_depth=6
# [351]#011train-rmse:0.19242#011validation-rmse:0.309147
# [04:55:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 2 pruned nodes, max_depth=6
# [352]#011train-rmse:0.192323#011validation-rmse:0.309209
# [04:55:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [353]#011train-rmse:0.192081#011validation-rmse:0.309245
# [04:55:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=6
# [354]#011train-rmse:0.191965#011validation-rmse:0.30918
# [04:55:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 2 pruned nodes, max_depth=6
# [355]#011train-rmse:0.191749#011validation-rmse:0.309148
# Stopping. Best iteration:
# [345]#011train-rmse:0.193412#011validation-rmse:0.309021
#
# Training seconds: 584
# Billable seconds: 584

# %% [markdown]
# Now that we have an estimator object attached to the correct training job, we can proceed as we normally would and create a transformer object.

# %%
# TODO: Create a transformer object from the attached estimator. Using an instance count of 1 and an instance type of ml.m4.xlarge
#       should be more than enough.

xgb_transformer = xgb_attached.transformer(instance_count = 1, instance_type = 'ml.m4.xlarge')

# %% [markdown]
# Next we actually perform the transform job. When doing so we need to make sure to specify the type of data we are sending so that it is serialized correctly in the background. In our case we are providing our model with csv data so we specify `text/csv`. Also, if the test data that we have provided is too large to process all at once then we need to specify how the data file should be split up. Since each line is a single entry in our data set we tell SageMaker that it can split the input on each line.

# %%
# TODO: Start the transform job. Make sure to specify the content type and the split type of the test data.

xgb_transformer.transform(test_location, content_type='text/csv', split_type='Line')

# %% [markdown]
# Currently the transform job is running but it is doing so in the background. Since we wish to wait until the transform job is done and we would like a bit of feedback we can run the `wait()` method.

# %%
xgb_transformer.wait()
# Out:
# .....................Arguments: serve
# [2020-02-05 05:12:21 +0000] [1] [INFO] Starting gunicorn 19.7.1
# [2020-02-05 05:12:21 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2020-02-05 05:12:21 +0000] [1] [INFO] Using worker: gevent
# [2020-02-05 05:12:21 +0000] [37] [INFO] Booting worker with pid: 37
# [2020-02-05 05:12:21 +0000] [38] [INFO] Booting worker with pid: 38
# [2020-02-05 05:12:21 +0000] [39] [INFO] Booting worker with pid: 39
# [2020-02-05:05:12:21:INFO] Model loaded successfully for worker : 37
# [2020-02-05:05:12:21:INFO] Model loaded successfully for worker : 38
# [2020-02-05 05:12:21 +0000] [40] [INFO] Booting worker with pid: 40
# [2020-02-05:05:12:21:INFO] Model loaded successfully for worker : 39
# [2020-02-05:05:12:21:INFO] Model loaded successfully for worker : 40
# 2020-02-05T05:12:44.112:[sagemaker logs]: MaxConcurrentTransforms=4, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
# [2020-02-05:05:12:46:INFO] Sniff delimiter as ','
# [2020-02-05:05:12:46:INFO] Sniff delimiter as ','
# [2020-02-05:05:12:46:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:12:47:INFO] Sniff delimiter as ','
# [2020-02-05:05:12:47:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:12:47:INFO] Sniff delimiter as ','
# [2020-02-05:05:12:47:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:12:46:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:12:47:INFO] Sniff delimiter as ','
# [2020-02-05:05:12:47:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:12:47:INFO] Sniff delimiter as ','
# [2020-02-05:05:12:47:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:12:48:INFO] Sniff delimiter as ','
# [2020-02-05:05:12:48:INFO] Sniff delimiter as ','
# [2020-02-05:05:12:48:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:12:48:INFO] Sniff delimiter as ','
# [2020-02-05:05:12:48:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:12:48:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:12:48:INFO] Sniff delimiter as ','
# [2020-02-05:05:12:48:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:12:49:INFO] Sniff delimiter as ','
# [2020-02-05:05:12:49:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:12:49:INFO] Sniff delimiter as ','
# [2020-02-05:05:12:49:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:12:50:INFO] Sniff delimiter as ','
# [2020-02-05:05:12:50:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:12:50:INFO] Sniff delimiter as ','
# [2020-02-05:05:12:50:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:12:50:INFO] Sniff delimiter as ','
# [2020-02-05:05:12:50:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:12:50:INFO] Sniff delimiter as ','
# [2020-02-05:05:12:50:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:12:50:INFO] Sniff delimiter as ','
# [2020-02-05:05:12:50:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:12:50:INFO] Sniff delimiter as ','
# [2020-02-05:05:12:50:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:12:53:INFO] Sniff delimiter as ','
# [2020-02-05:05:12:53:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:12:53:INFO] Sniff delimiter as ','
# [2020-02-05:05:12:53:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:12:54:INFO] Sniff delimiter as ','
# [2020-02-05:05:12:54:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:12:54:INFO] Sniff delimiter as ','
# [2020-02-05:05:12:54:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:12:55:INFO] Sniff delimiter as ','
# [2020-02-05:05:12:55:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:12:55:INFO] Sniff delimiter as ','
# [2020-02-05:05:12:55:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:12:55:INFO] Sniff delimiter as ','
# [2020-02-05:05:12:55:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:12:55:INFO] Sniff delimiter as ','
# [2020-02-05:05:12:55:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:12:55:INFO] Sniff delimiter as ','
# [2020-02-05:05:12:55:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:12:55:INFO] Sniff delimiter as ','
# [2020-02-05:05:12:55:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:12:57:INFO] Sniff delimiter as ','
# [2020-02-05:05:12:57:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:12:57:INFO] Sniff delimiter as ','
# [2020-02-05:05:12:57:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:12:57:INFO] Sniff delimiter as ','
# [2020-02-05:05:12:57:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:12:57:INFO] Sniff delimiter as ','
# [2020-02-05:05:12:57:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:12:57:INFO] Sniff delimiter as ','
# [2020-02-05:05:12:57:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:12:57:INFO] Sniff delimiter as ','
# [2020-02-05:05:12:57:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:12:57:INFO] Sniff delimiter as ','
# [2020-02-05:05:12:57:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:12:57:INFO] Sniff delimiter as ','
# [2020-02-05:05:12:57:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:13:00:INFO] Sniff delimiter as ','
# [2020-02-05:05:13:00:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:13:00:INFO] Sniff delimiter as ','
# [2020-02-05:05:13:00:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:13:00:INFO] Sniff delimiter as ','
# [2020-02-05:05:13:00:INFO] Sniff delimiter as ','
# [2020-02-05:05:13:00:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:13:00:INFO] Sniff delimiter as ','
# [2020-02-05:05:13:00:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:13:00:INFO] Sniff delimiter as ','
# [2020-02-05:05:13:00:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:13:00:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:13:00:INFO] Sniff delimiter as ','
# [2020-02-05:05:13:00:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:13:00:INFO] Sniff delimiter as ','
# [2020-02-05:05:13:00:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:13:02:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:13:02:INFO] Sniff delimiter as ','
# [2020-02-05:05:13:02:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:13:02:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:13:02:INFO] Sniff delimiter as ','
# [2020-02-05:05:13:02:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:13:04:INFO] Sniff delimiter as ','
# [2020-02-05:05:13:04:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:13:04:INFO] Sniff delimiter as ','
# [2020-02-05:05:13:04:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:13:05:INFO] Sniff delimiter as ','
# [2020-02-05:05:13:05:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:13:04:INFO] Sniff delimiter as ','
# [2020-02-05:05:13:04:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:13:04:INFO] Sniff delimiter as ','
# [2020-02-05:05:13:04:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:13:05:INFO] Sniff delimiter as ','
# [2020-02-05:05:13:05:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:13:05:INFO] Sniff delimiter as ','
# [2020-02-05:05:13:05:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:13:05:INFO] Sniff delimiter as ','
# [2020-02-05:05:13:05:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:13:07:INFO] Sniff delimiter as ','
# [2020-02-05:05:13:07:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:13:07:INFO] Sniff delimiter as ','
# [2020-02-05:05:13:07:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:13:07:INFO] Sniff delimiter as ','
# [2020-02-05:05:13:07:INFO] Sniff delimiter as ','
# [2020-02-05:05:13:07:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:13:07:INFO] Sniff delimiter as ','
# [2020-02-05:05:13:07:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:13:07:INFO] Sniff delimiter as ','
# [2020-02-05:05:13:07:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:13:07:INFO] Sniff delimiter as ','
# [2020-02-05:05:13:07:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:13:07:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:13:07:INFO] Sniff delimiter as ','
# [2020-02-05:05:13:07:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:13:09:INFO] Sniff delimiter as ','
# [2020-02-05:05:13:09:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:13:09:INFO] Sniff delimiter as ','
# [2020-02-05:05:13:09:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:13:09:INFO] Sniff delimiter as ','
# [2020-02-05:05:13:09:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:13:09:INFO] Sniff delimiter as ','
# [2020-02-05:05:13:09:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:13:09:INFO] Sniff delimiter as ','
# [2020-02-05:05:13:09:INFO] Determined delimiter of CSV input is ','
# [2020-02-05:05:13:09:INFO] Sniff delimiter as ','
# [2020-02-05:05:13:09:INFO] Determined delimiter of CSV input is ','

# %% [markdown]
# Now the transform job has executed and the result, the estimated sentiment of each review, has been saved on S3. Since we would rather work on this file locally we can perform a bit of notebook magic to copy the file to the `data_dir`.

# %%
# !aws s3 cp --recursive $xgb_transformer.output_path $data_dir
# Out:
# download: s3://sagemaker-us-east-1-174814400447/xgboost-200205-0443-003-6bf64d63-2020-02-05-05-08-55-119/test.csv.out to ../data/xgboost/test.csv.out

# %% [markdown]
# The last step is now to read in the output from our model, convert the output to something a little more usable, in this case we want the sentiment to be either `1` (positive) or `0` (negative), and then compare to the ground truth labels.

# %%
predictions = pd.read_csv(os.path.join(data_dir, 'test.csv.out'), header=None)
predictions = [round(num) for num in predictions.squeeze().values]

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test_y, predictions)
# Out:
# 0.87092

# %% [markdown]
# ## Optional: Clean up
#
# The default notebook instance on SageMaker doesn't have a lot of excess disk space available. As you continue to complete and execute notebooks you will eventually fill up this disk space, leading to errors which can be difficult to diagnose. Once you are completely finished using a notebook it is a good idea to remove the files that you created along the way. Of course, you can do this from the terminal or from the notebook hub if you would like. The cell below contains some commands to clean up the created files from within the notebook.

# %%
# First we will remove all of the files contained in the data_dir directory
# !rm $data_dir/*

# And then we delete the directory itself
# !rmdir $data_dir

# Similarly we will remove the files in the cache_dir directory and the directory itself
# !rm $cache_dir/*
# !rmdir $cache_dir
