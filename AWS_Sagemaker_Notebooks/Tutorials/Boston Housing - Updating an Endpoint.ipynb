# %% [markdown]
# # Predicting Boston Housing Prices
#
# ## Updating a model using SageMaker
#
# _Deep Learning Nanodegree Program | Deployment_
#
# ---
#
# In this notebook, we will continue working with the [Boston Housing Dataset](https://www.cs.toronto.edu/~delve/data/boston/bostonDetail.html). Our goal in this notebook will be to train two different models and to use SageMaker to switch a deployed endpoint from using one model to the other. One of the benefits of using SageMaker to do this is that we can make the change without interrupting service. What this means is that we can continue sending data to the endpoint and at no point will that endpoint disappear.
#
# ## General Outline
#
# Typically, when using a notebook instance with SageMaker, you will proceed through the following steps. Of course, not every step will need to be done with each project. Also, there is quite a lot of room for variation in many of the steps, as you will see throughout these lessons.
#
# 1. Download or otherwise retrieve the data.
# 2. Process / Prepare the data.
# 3. Upload the processed data to S3.
# 4. Train a chosen model.
# 5. Test the trained model (typically using a batch transform job).
# 6. Deploy the trained model.
# 7. Use the deployed model.
#
# In this notebook we will be skipping step 5, testing the model. In addition, we will perform steps 4, 6 and 7 multiple times with different models.

# %% [markdown]
# ## Step 0: Setting up the notebook
#
# We begin by setting up all of the necessary bits required to run our notebook. To start that means loading all of the Python modules we will need.

# %%
# %matplotlib inline

import os

import numpy as np
import pandas as pd

from pprint import pprint
import matplotlib.pyplot as plt
from time import gmtime, strftime

from sklearn.datasets import load_boston
import sklearn.model_selection

# %% [markdown]
# In addition to the modules above, we need to import the various bits of SageMaker that we will be using.

# %%
import sagemaker
from sagemaker import get_execution_role
from sagemaker.amazon.amazon_estimator import get_image_uri
from sagemaker.predictor import csv_serializer

# This is an object that represents the SageMaker session that we are currently operating in. This
# object contains some useful information that we will need to access later such as our region.
session = sagemaker.Session()

# This is an object that represents the IAM role that we are currently assigned. When we construct
# and launch the training job later we will need to tell it what IAM role it should have. Since our
# use case is relatively simple we will simply assign the training job the role we currently have.
role = get_execution_role()

# %% [markdown]
# ## Step 1: Downloading the data
#
# Fortunately, this dataset can be retrieved using sklearn and so this step is relatively straightforward.

# %%
boston = load_boston()

# %% [markdown]
# ## Step 2: Preparing and splitting the data
#
# Given that this is clean tabular data, we don't need to do any processing. However, we do need to split the rows in the dataset up into train, test and validation sets.

# %%
# First we package up the input data and the target variable (the median value) as pandas dataframes. This
# will make saving the data to a file a little easier later on.

X_bos_pd = pd.DataFrame(boston.data, columns=boston.feature_names)
Y_bos_pd = pd.DataFrame(boston.target)

# We split the dataset into 2/3 training and 1/3 testing sets.
X_train, X_test, Y_train, Y_test = sklearn.model_selection.train_test_split(X_bos_pd, Y_bos_pd, test_size=0.33)

# Then we split the training set further into 2/3 training and 1/3 validation sets.
X_train, X_val, Y_train, Y_val = sklearn.model_selection.train_test_split(X_train, Y_train, test_size=0.33)

# %% [markdown]
# ## Step 3: Uploading the training and validation files to S3
#
# When a training job is constructed using SageMaker, a container is executed which performs the training operation. This container is given access to data that is stored in S3. This means that we need to upload the data we want to use for training to S3. We can use the SageMaker API to do this and hide some of the details.
#
# ### Save the data locally
#
# First we need to create the train and validation csv files which we will then upload to S3.

# %%
# This is our local data directory. We need to make sure that it exists.
data_dir = '../data/boston'
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

# %%
# We use pandas to save our train and validation data to csv files. Note that we make sure not to include header
# information or an index as this is required by the built in algorithms provided by Amazon. Also, it is assumed
# that the first entry in each row is the target variable.

pd.concat([Y_val, X_val], axis=1).to_csv(os.path.join(data_dir, 'validation.csv'), header=False, index=False)
pd.concat([Y_train, X_train], axis=1).to_csv(os.path.join(data_dir, 'train.csv'), header=False, index=False)

# %% [markdown]
# ### Upload to S3
#
# Since we are currently running inside of a SageMaker session, we can use the object which represents this session to upload our data to the 'default' S3 bucket. Note that it is good practice to provide a custom prefix (essentially an S3 folder) to make sure that you don't accidentally interfere with data uploaded from some other notebook or project.

# %%
prefix = 'boston-update-endpoints'

val_location = session.upload_data(os.path.join(data_dir, 'validation.csv'), key_prefix=prefix)
train_location = session.upload_data(os.path.join(data_dir, 'train.csv'), key_prefix=prefix)

# %% [markdown]
# ## Step 4 (A): Train the XGBoost model
#
# Now that we have the training and validation data uploaded to S3, we can construct our XGBoost model and train it. We will be making use of the high level SageMaker API to do this which will make the resulting code a little easier to read at the cost of some flexibility.
#
# To construct an estimator, the object which we wish to train, we need to provide the location of a container which contains the training code. Since we are using a built in algorithm this container is provided by Amazon. However, the full name of the container is a bit lengthy and depends on the region that we are operating in. Fortunately, SageMaker provides a useful utility method called `get_image_uri` that constructs the image name for us.
#
# To use the `get_image_uri` method we need to provide it with our current region, which can be obtained from the session object, and the name of the algorithm we wish to use. In this notebook we will be using XGBoost however you could try another algorithm if you wish. The list of built in algorithms can be found in the list of [Common Parameters](https://docs.aws.amazon.com/sagemaker/latest/dg/sagemaker-algo-docker-registry-paths.html).

# %%
# As stated above, we use this utility method to construct the image name for the training container.
xgb_container = get_image_uri(session.boto_region_name, 'xgboost')

# Now that we know which container to use, we can construct the estimator object.
xgb = sagemaker.estimator.Estimator(xgb_container, # The name of the training container
                                    role,      # The IAM role to use (our current role in this case)
                                    train_instance_count=1, # The number of instances to use for training
                                    train_instance_type='ml.m4.xlarge', # The type of instance ot use for training
                                    output_path='s3://{}/{}/output'.format(session.default_bucket(), prefix),
                                                                        # Where to save the output (the model artifacts)
                                    sagemaker_session=session) # The current SageMaker session
# Out:
# WARNING:root:There is a more up to date SageMaker XGBoost image. To use the newer image, please set 'repo_version'='0.90-1'. For example:
# 	get_image_uri(region, 'xgboost', '0.90-1').

# %% [markdown]
# Before asking SageMaker to begin the training job, we should probably set any model specific hyperparameters. There are quite a few that can be set when using the XGBoost algorithm, below are just a few of them. If you would like to change the hyperparameters below or modify additional ones you can find additional information on the [XGBoost hyperparameter page](https://docs.aws.amazon.com/sagemaker/latest/dg/xgboost_hyperparameters.html)

# %%
xgb.set_hyperparameters(max_depth=5,
                        eta=0.2,
                        gamma=4,
                        min_child_weight=6,
                        subsample=0.8,
                        objective='reg:linear',
                        early_stopping_rounds=10,
                        num_round=200)

# %% [markdown]
# Now that we have our estimator object completely set up, it is time to train it. To do this we make sure that SageMaker knows our input data is in csv format and then execute the `fit` method.

# %%
# This is a wrapper around the location of our train and validation data, to make sure that SageMaker
# knows our data is in csv format.
s3_input_train = sagemaker.s3_input(s3_data=train_location, content_type='text/csv')
s3_input_validation = sagemaker.s3_input(s3_data=val_location, content_type='text/csv')

xgb.fit({'train': s3_input_train, 'validation': s3_input_validation})
# Out:
# 2020-02-06 16:07:58 Starting - Starting the training job...
# 2020-02-06 16:08:00 Starting - Launching requested ML instances......
# 2020-02-06 16:09:04 Starting - Preparing the instances for training......
# 2020-02-06 16:10:15 Downloading - Downloading input data...
# 2020-02-06 16:10:59 Training - Training image download completed. Training in progress..Arguments: train
# [2020-02-06:16:11:00:INFO] Running standalone xgboost training.
# [2020-02-06:16:11:00:INFO] File size need to be processed in the node: 0.02mb. Available memory size in the node: 8514.01mb
# [2020-02-06:16:11:00:INFO] Determined delimiter of CSV input is ','
# [16:11:00] S3DistributionType set as FullyReplicated
# [16:11:00] 227x13 matrix with 2951 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2020-02-06:16:11:00:INFO] Determined delimiter of CSV input is ','
# [16:11:00] S3DistributionType set as FullyReplicated
# [16:11:00] 112x13 matrix with 1456 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [16:11:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [0]#011train-rmse:19.0579#011validation-rmse:19.3253
# Multiple eval metrics have been passed: 'validation-rmse' will be used for early stopping.
#
# Will train until validation-rmse hasn't improved in 10 rounds.
# [16:11:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [1]#011train-rmse:15.6713#011validation-rmse:15.7768
# [16:11:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=3
# [2]#011train-rmse:12.9175#011validation-rmse:12.9708
# [16:11:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=4
# [3]#011train-rmse:10.7502#011validation-rmse:10.7072
# [16:11:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [4]#011train-rmse:8.99024#011validation-rmse:8.93044
# [16:11:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [5]#011train-rmse:7.5906#011validation-rmse:7.60354
# [16:11:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 2 pruned nodes, max_depth=5
# [6]#011train-rmse:6.39843#011validation-rmse:6.4358
# [16:11:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [7]#011train-rmse:5.41194#011validation-rmse:5.41411
# [16:11:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 2 pruned nodes, max_depth=5
# [8]#011train-rmse:4.67645#011validation-rmse:4.69377
# [16:11:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [9]#011train-rmse:4.09934#011validation-rmse:4.20443
# [16:11:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [10]#011train-rmse:3.60455#011validation-rmse:3.82497
# [16:11:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 2 pruned nodes, max_depth=5
# [11]#011train-rmse:3.31357#011validation-rmse:3.5392
# [16:11:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [12]#011train-rmse:3.00367#011validation-rmse:3.32551
# [16:11:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [13]#011train-rmse:2.76412#011validation-rmse:3.19006
# [16:11:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [14]#011train-rmse:2.59609#011validation-rmse:3.06787
# [16:11:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [15]#011train-rmse:2.44342#011validation-rmse:2.97136
# [16:11:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 2 pruned nodes, max_depth=5
# [16]#011train-rmse:2.30983#011validation-rmse:2.89533
# [16:11:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [17]#011train-rmse:2.18269#011validation-rmse:2.84537
# [16:11:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [18]#011train-rmse:2.1376#011validation-rmse:2.78694
# [16:11:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [19]#011train-rmse:2.08293#011validation-rmse:2.78228
# [16:11:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [20]#011train-rmse:2.03436#011validation-rmse:2.76975
# [16:11:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 4 pruned nodes, max_depth=5
# [21]#011train-rmse:1.92835#011validation-rmse:2.77389
# [16:11:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [22]#011train-rmse:1.88769#011validation-rmse:2.77663
# [16:11:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [23]#011train-rmse:1.85286#011validation-rmse:2.7717
# [16:11:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 4 pruned nodes, max_depth=5
# [24]#011train-rmse:1.78238#011validation-rmse:2.77178
# [16:11:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 2 pruned nodes, max_depth=5
# [25]#011train-rmse:1.72677#011validation-rmse:2.78647
# [16:11:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 2 pruned nodes, max_depth=5
# [26]#011train-rmse:1.67593#011validation-rmse:2.79819
# [16:11:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 2 pruned nodes, max_depth=5
# [27]#011train-rmse:1.63124#011validation-rmse:2.7926
# [16:11:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 4 pruned nodes, max_depth=5
# [28]#011train-rmse:1.60426#011validation-rmse:2.81087
# [16:11:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [29]#011train-rmse:1.58808#011validation-rmse:2.80088
# [16:11:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 4 pruned nodes, max_depth=5
# [30]#011train-rmse:1.53943#011validation-rmse:2.82731
# Stopping. Best iteration:
# [20]#011train-rmse:2.03436#011validation-rmse:2.76975
#
#
# 2020-02-06 16:11:12 Uploading - Uploading generated training model
# 2020-02-06 16:11:12 Completed - Training job completed
# Training seconds: 57
# Billable seconds: 57

# %% [markdown]
# ## Step 5: Test the trained model
#
# We will be skipping this step for now.
#
#
# ## Step 6 (A): Deploy the trained model
#
# Even though we used the high level approach to construct and train the XGBoost model, we will be using the lower level approach to deploy it. One of the reasons for this is so that we have additional control over how the endpoint is constructed. This will be a little more clear later on when construct more advanced endpoints.
#
# ### Build the model
#
# Of course, before we can deploy the model, we need to first create it. The `fit` method that we used earlier created some model artifacts and we can use these to construct a model object.

# %%
# Remember that a model needs to have a unique name
xgb_model_name = "boston-update-xgboost-model" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

# We also need to tell SageMaker which container should be used for inference and where it should
# retrieve the model artifacts from. In our case, the xgboost container that we used for training
# can also be used for inference and the model artifacts come from the previous call to fit.
xgb_primary_container = {
    "Image": xgb_container,
    "ModelDataUrl": xgb.model_data
}

# And lastly we construct the SageMaker model
xgb_model_info = session.sagemaker_client.create_model(
                                ModelName = xgb_model_name,
                                ExecutionRoleArn = role,
                                PrimaryContainer = xgb_primary_container)

# %% [markdown]
# ### Create the endpoint configuration
#
# Once we have a model we can start putting together the endpoint. Recall that to do this we need to first create an endpoint configuration, essentially the blueprint that SageMaker will use to build the endpoint itself.

# %%
# As before, we need to give our endpoint configuration a name which should be unique
xgb_endpoint_config_name = "boston-update-xgboost-endpoint-config-" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

# And then we ask SageMaker to construct the endpoint configuration
xgb_endpoint_config_info = session.sagemaker_client.create_endpoint_config(
                            EndpointConfigName = xgb_endpoint_config_name,
                            ProductionVariants = [{
                                "InstanceType": "ml.m4.xlarge",
                                "InitialVariantWeight": 1,
                                "InitialInstanceCount": 1,
                                "ModelName": xgb_model_name,
                                "VariantName": "XGB-Model"
                            }])

# %% [markdown]
# ### Deploy the endpoint
#
# Now that the endpoint configuration has been created, we can ask SageMaker to build our endpoint.
#
# **Note:** This is a friendly (repeated) reminder that you are about to deploy an endpoint. Make sure that you shut it down once you've finished with it!

# %%
# Again, we need a unique name for our endpoint
endpoint_name = "boston-update-endpoint-" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

# And then we can deploy our endpoint
endpoint_info = session.sagemaker_client.create_endpoint(
                    EndpointName = endpoint_name,
                    EndpointConfigName = xgb_endpoint_config_name)

# %%
endpoint_dec = session.wait_for_endpoint(endpoint_name)
# Out:
# -------------------!

# %% [markdown]
# ## Step 7 (A): Use the model
#
# Now that our model is trained and deployed we can send some test data to it and evaluate the results.

# %%
response = session.sagemaker_runtime_client.invoke_endpoint(
                                                EndpointName = endpoint_name,
                                                ContentType = 'text/csv',
                                                Body = ','.join(map(str, X_test.values[0])))

# %%
pprint(response)
# Out:
# {'Body': <botocore.response.StreamingBody object at 0x7f0f34111860>,
#  'ContentType': 'text/csv; charset=utf-8',
#  'InvokedProductionVariant': 'XGB-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '13',
#                                       'content-type': 'text/csv; charset=utf-8',
#                                       'date': 'Thu, 6 Feb 2020 16:21:14 GMT',
#                                       'x-amzn-invoked-production-variant': 'XGB-Model',
#                                       'x-amzn-requestid': 'a183d23f-914f-4444-aa7c-4b09df8f1901'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': 'a183d23f-914f-4444-aa7c-4b09df8f1901',
#                       'RetryAttempts': 0}}

# %%
result = response['Body'].read().decode("utf-8")

# %%
pprint(result)
# Out:
# '32.9431877136'

# %%
Y_test.values[0]
# Out:
# array([34.9])

# %% [markdown]
# ## Shut down the endpoint
#
# Now that we know that the XGBoost endpoint works, we can shut it down. We will make use of it again later.

# %%
ession.sagemaker_client.delete_endpoint(EndpointName = endpoint_name)
# Out:
# {'ResponseMetadata': {'RequestId': 'e25d317a-af3c-4fc8-981c-549ba56b3e73',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'e25d317a-af3c-4fc8-981c-549ba56b3e73',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '0',
#    'date': 'Thu, 06 Feb 2020 16:21:13 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ## Step 4 (B): Train the Linear model
#
# Suppose we are working in an environment where the XGBoost model that we trained earlier is becoming too costly. Perhaps the number of calls to our endpoint has increased and the length of time it takes to perform inference with the XGBoost model is becoming problematic.
#
# A possible solution might be to train a simpler model to see if it performs nearly as well. In our case, we will construct a linear model. The process of doing this is the same as for creating the XGBoost model that we created earlier, although there are different hyperparameters that we need to set.

# %%
# Similar to the XGBoost model, we will use the utility method to construct the image name for the training container.
linear_container = get_image_uri(session.boto_region_name, 'linear-learner')

# Now that we know which container to use, we can construct the estimator object.
linear = sagemaker.estimator.Estimator(linear_container, # The name of the training container
                                        role,      # The IAM role to use (our current role in this case)
                                        train_instance_count=1, # The number of instances to use for training
                                        train_instance_type='ml.m4.xlarge', # The type of instance ot use for training
                                        output_path='s3://{}/{}/output'.format(session.default_bucket(), prefix),
                                                                            # Where to save the output (the model artifacts)
                                        sagemaker_session=session) # The current SageMaker session

# %% [markdown]
# Before asking SageMaker to train our model, we need to set some hyperparameters. In this case we will be using a linear model so the number of hyperparameters we need to set is much fewer. For more details see the [Linear model hyperparameter page](https://docs.aws.amazon.com/sagemaker/latest/dg/ll_hyperparameters.html)

# %%
linear.set_hyperparameters(feature_dim=13, # Our data has 13 feature columns
                           predictor_type='regressor', # We wish to create a regression model
                           mini_batch_size=200) # Here we set how many samples to look at in each iteration

# %% [markdown]
# Now that the hyperparameters have been set, we can ask SageMaker to fit the linear model to our data.

# %%
linear.fit({'train': s3_input_train, 'validation': s3_input_validation})
# Out:
# 2020-02-06 16:21:14 Starting - Starting the training job...
# 2020-02-06 16:21:16 Starting - Launching requested ML instances......
# 2020-02-06 16:22:19 Starting - Preparing the instances for training.........
# 2020-02-06 16:24:11 Downloading - Downloading input data
# 2020-02-06 16:24:11 Training - Training image download completed. Training in progress..Docker entrypoint called with argument(s): train
# [02/06/2020 16:24:13 INFO 140381932189504] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [02/06/2020 16:24:13 INFO 140381932189504] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'13', u'mini_batch_size': u'200', u'predictor_type': u'regressor'}
# [02/06/2020 16:24:13 INFO 140381932189504] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'13', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'200', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'regressor', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [02/06/2020 16:24:13 WARNING 140381932189504] Loggers have already been setup.
# Process 1 is a worker.
# [02/06/2020 16:24:13 INFO 140381932189504] Using default worker.
# [02/06/2020 16:24:13 INFO 140381932189504] Create Store: local
# [02/06/2020 16:24:13 INFO 140381932189504] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7face599f390>
# [02/06/2020 16:24:13 INFO 140381932189504] Scaling model computed with parameters:
#  {'stdev_weight':
# [8.4165821e+00 2.5471088e+01 6.7604361e+00 2.2798026e-01 1.2219636e-01
#  6.7050874e-01 2.8219824e+01 2.1037679e+00 8.5485067e+00 1.6466194e+02
#  2.2234542e+00 8.9924622e+01 7.0532050e+00]
# <NDArray 13 @cpu(0)>, 'stdev_label':
# [8.861467]
# <NDArray 1 @cpu(0)>, 'mean_label':
# [21.648998]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [3.4416540e+00 1.2622500e+01 1.0919351e+01 5.5000000e-02 5.5672050e-01
#  6.2525096e+00 6.9949501e+01 3.8120000e+00 9.1949997e+00 4.0402499e+02
#  1.8301500e+01 3.5628519e+02 1.2931950e+01]
# <NDArray 13 @cpu(0)>}
# [02/06/2020 16:24:13 INFO 140381932189504] nvidia-smi took: 0.0251820087433 secs to identify 0 gpus
# [02/06/2020 16:24:13 INFO 140381932189504] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 2, "sum": 2.0, "min": 2}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 3, "sum": 3.0, "min": 3}, "Total Records Seen": {"count": 1, "max": 427, "sum": 427.0, "min": 427}, "Max Records Seen Between Resets": {"count": 1, "max": 227, "sum": 227.0, "min": 227}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1581006253.786111, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1581006253.786072}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9692208862304688, "sum": 0.9692208862304688, "min": 0.9692208862304688}}, "EndTime": 1581006253.821852, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.821795}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.86052978515625, "sum": 0.86052978515625, "min": 0.86052978515625}}, "EndTime": 1581006253.821937, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.821916}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.3637205505371093, "sum": 1.3637205505371093, "min": 1.3637205505371093}}, "EndTime": 1581006253.82201, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.82199}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8793875885009765, "sum": 0.8793875885009765, "min": 0.8793875885009765}}, "EndTime": 1581006253.822071, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.822053}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.861665267944336, "sum": 0.861665267944336, "min": 0.861665267944336}}, "EndTime": 1581006253.822144, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.822125}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0398869323730469, "sum": 1.0398869323730469, "min": 1.0398869323730469}}, "EndTime": 1581006253.822208, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.822191}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.150587921142578, "sum": 1.150587921142578, "min": 1.150587921142578}}, "EndTime": 1581006253.82227, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.822254}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1193368530273438, "sum": 1.1193368530273438, "min": 1.1193368530273438}}, "EndTime": 1581006253.822338, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.82232}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9210916900634766, "sum": 0.9210916900634766, "min": 0.9210916900634766}}, "EndTime": 1581006253.822403, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.822386}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.4436260986328124, "sum": 1.4436260986328124, "min": 1.4436260986328124}}, "EndTime": 1581006253.822468, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.822451}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8639052581787109, "sum": 0.8639052581787109, "min": 0.8639052581787109}}, "EndTime": 1581006253.822536, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.822518}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1133206939697267, "sum": 1.1133206939697267, "min": 1.1133206939697267}}, "EndTime": 1581006253.82259, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.822573}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0113680267333984, "sum": 1.0113680267333984, "min": 1.0113680267333984}}, "EndTime": 1581006253.822661, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.822643}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0331844329833983, "sum": 1.0331844329833983, "min": 1.0331844329833983}}, "EndTime": 1581006253.822733, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.822714}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8670885467529297, "sum": 0.8670885467529297, "min": 0.8670885467529297}}, "EndTime": 1581006253.822807, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.822788}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0409141540527345, "sum": 1.0409141540527345, "min": 1.0409141540527345}}, "EndTime": 1581006253.822875, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.822858}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0450608825683594, "sum": 1.0450608825683594, "min": 1.0450608825683594}}, "EndTime": 1581006253.822929, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.822917}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8412696838378906, "sum": 0.8412696838378906, "min": 0.8412696838378906}}, "EndTime": 1581006253.822989, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.822973}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.2282636260986328, "sum": 1.2282636260986328, "min": 1.2282636260986328}}, "EndTime": 1581006253.823051, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.823034}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.040675277709961, "sum": 1.040675277709961, "min": 1.040675277709961}}, "EndTime": 1581006253.823104, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.823088}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7714045715332031, "sum": 0.7714045715332031, "min": 0.7714045715332031}}, "EndTime": 1581006253.823176, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.823158}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1607032775878907, "sum": 1.1607032775878907, "min": 1.1607032775878907}}, "EndTime": 1581006253.823248, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.82323}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7545609283447265, "sum": 0.7545609283447265, "min": 0.7545609283447265}}, "EndTime": 1581006253.823318, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.823301}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8548779296875, "sum": 0.8548779296875, "min": 0.8548779296875}}, "EndTime": 1581006253.823386, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.823367}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9547918701171875, "sum": 0.9547918701171875, "min": 0.9547918701171875}}, "EndTime": 1581006253.823448, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.823431}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9405994415283203, "sum": 0.9405994415283203, "min": 0.9405994415283203}}, "EndTime": 1581006253.823515, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.823498}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.2584735107421876, "sum": 1.2584735107421876, "min": 1.2584735107421876}}, "EndTime": 1581006253.823577, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.82356}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.14397705078125, "sum": 1.14397705078125, "min": 1.14397705078125}}, "EndTime": 1581006253.823638, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.823621}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0242823028564454, "sum": 1.0242823028564454, "min": 1.0242823028564454}}, "EndTime": 1581006253.823697, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.82368}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9269655609130859, "sum": 0.9269655609130859, "min": 0.9269655609130859}}, "EndTime": 1581006253.823761, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.823743}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.140662307739258, "sum": 1.140662307739258, "min": 1.140662307739258}}, "EndTime": 1581006253.82382, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.823809}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.127961654663086, "sum": 1.127961654663086, "min": 1.127961654663086}}, "EndTime": 1581006253.823878, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.823862}
#
# [02/06/2020 16:24:13 INFO 140381932189504] #quality_metric: host=algo-1, epoch=0, train mse_objective <loss>=0.96922088623
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 77.59272112165179, "sum": 77.59272112165179, "min": 77.59272112165179}}, "EndTime": 1581006253.869407, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.86935}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 73.29228864397321, "sum": 73.29228864397321, "min": 73.29228864397321}}, "EndTime": 1581006253.869479, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.869463}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 108.45929827008929, "sum": 108.45929827008929, "min": 108.45929827008929}}, "EndTime": 1581006253.869555, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.869536}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 72.15481131417411, "sum": 72.15481131417411, "min": 72.15481131417411}}, "EndTime": 1581006253.869614, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.869601}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 62.52813720703125, "sum": 62.52813720703125, "min": 62.52813720703125}}, "EndTime": 1581006253.869676, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.869658}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 42.054029192243306, "sum": 42.054029192243306, "min": 42.054029192243306}}, "EndTime": 1581006253.869751, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.869732}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 54.57757568359375, "sum": 54.57757568359375, "min": 54.57757568359375}}, "EndTime": 1581006253.86983, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.869811}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 56.17943899972098, "sum": 56.17943899972098, "min": 56.17943899972098}}, "EndTime": 1581006253.869906, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.869887}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 80.25660051618304, "sum": 80.25660051618304, "min": 80.25660051618304}}, "EndTime": 1581006253.869976, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.869958}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 116.90006801060268, "sum": 116.90006801060268, "min": 116.90006801060268}}, "EndTime": 1581006253.870048, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.870029}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 71.6896493094308, "sum": 71.6896493094308, "min": 71.6896493094308}}, "EndTime": 1581006253.870122, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.870103}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 93.36090087890625, "sum": 93.36090087890625, "min": 93.36090087890625}}, "EndTime": 1581006253.870192, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.870175}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 54.570277622767854, "sum": 54.570277622767854, "min": 54.570277622767854}}, "EndTime": 1581006253.870263, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.870245}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 61.425611223493306, "sum": 61.425611223493306, "min": 61.425611223493306}}, "EndTime": 1581006253.870325, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.870308}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 62.530857631138396, "sum": 62.530857631138396, "min": 62.530857631138396}}, "EndTime": 1581006253.870386, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.870369}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 45.45310320172991, "sum": 45.45310320172991, "min": 45.45310320172991}}, "EndTime": 1581006253.870448, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.870431}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 87.89654541015625, "sum": 87.89654541015625, "min": 87.89654541015625}}, "EndTime": 1581006253.870516, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.870499}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 71.03599330357143, "sum": 71.03599330357143, "min": 71.03599330357143}}, "EndTime": 1581006253.870576, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.870559}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 102.60546875, "sum": 102.60546875, "min": 102.60546875}}, "EndTime": 1581006253.870633, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.870616}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 87.54291643415179, "sum": 87.54291643415179, "min": 87.54291643415179}}, "EndTime": 1581006253.870701, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.870683}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 60.83420671735491, "sum": 60.83420671735491, "min": 60.83420671735491}}, "EndTime": 1581006253.870765, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.870747}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 53.26707240513393, "sum": 53.26707240513393, "min": 53.26707240513393}}, "EndTime": 1581006253.870826, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.870809}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 49.79822213309152, "sum": 49.79822213309152, "min": 49.79822213309152}}, "EndTime": 1581006253.870891, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.870873}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 52.342215401785715, "sum": 52.342215401785715, "min": 52.342215401785715}}, "EndTime": 1581006253.870948, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.870929}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 83.88985770089286, "sum": 83.88985770089286, "min": 83.88985770089286}}, "EndTime": 1581006253.871017, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.870999}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 83.48197719029018, "sum": 83.48197719029018, "min": 83.48197719029018}}, "EndTime": 1581006253.871083, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.871065}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 100.04136439732143, "sum": 100.04136439732143, "min": 100.04136439732143}}, "EndTime": 1581006253.87114, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.871124}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 97.10703822544643, "sum": 97.10703822544643, "min": 97.10703822544643}}, "EndTime": 1581006253.8712, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.871183}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 93.32252720424107, "sum": 93.32252720424107, "min": 93.32252720424107}}, "EndTime": 1581006253.871258, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.871241}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 109.54103306361607, "sum": 109.54103306361607, "min": 109.54103306361607}}, "EndTime": 1581006253.871324, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.871306}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 85.60712541852679, "sum": 85.60712541852679, "min": 85.60712541852679}}, "EndTime": 1581006253.871388, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.871371}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 84.29529680524554, "sum": 84.29529680524554, "min": 84.29529680524554}}, "EndTime": 1581006253.871445, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.871429}
#
# [02/06/2020 16:24:13 INFO 140381932189504] #quality_metric: host=algo-1, epoch=0, validation mse_objective <loss>=77.5927211217
# [02/06/2020 16:24:13 INFO 140381932189504] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=mse_objective, value=42.0540291922
# [02/06/2020 16:24:13 INFO 140381932189504] Epoch 0: Loss improved. Updating best model
# [02/06/2020 16:24:13 INFO 140381932189504] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 2, "sum": 2.0, "min": 2}, "Number of Batches Since Last Reset": {"count": 1, "max": 2, "sum": 2.0, "min": 2}, "Number of Records Since Last Reset": {"count": 1, "max": 227, "sum": 227.0, "min": 227}, "Total Batches Seen": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Total Records Seen": {"count": 1, "max": 654, "sum": 654.0, "min": 654}, "Max Records Seen Between Resets": {"count": 1, "max": 227, "sum": 227.0, "min": 227}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1581006253.873285, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581006253.786313}
#
# [02/06/2020 16:24:13 INFO 140381932189504] #throughput_metric: host=algo-1, train throughput=2606.55564864 records/second
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9130812072753907, "sum": 0.9130812072753907, "min": 0.9130812072753907}}, "EndTime": 1581006253.901234, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.901182}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8125095367431641, "sum": 0.8125095367431641, "min": 0.8125095367431641}}, "EndTime": 1581006253.901299, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.901287}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.2873744201660156, "sum": 1.2873744201660156, "min": 1.2873744201660156}}, "EndTime": 1581006253.901368, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.901349}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8303414916992188, "sum": 0.8303414916992188, "min": 0.8303414916992188}}, "EndTime": 1581006253.901441, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.901423}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.82659912109375, "sum": 0.82659912109375, "min": 0.82659912109375}}, "EndTime": 1581006253.901515, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.901495}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.5827457427978515, "sum": 0.5827457427978515, "min": 0.5827457427978515}}, "EndTime": 1581006253.90158, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.901562}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7410528564453125, "sum": 0.7410528564453125, "min": 0.7410528564453125}}, "EndTime": 1581006253.901645, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.901627}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7219143676757812, "sum": 0.7219143676757812, "min": 0.7219143676757812}}, "EndTime": 1581006253.901708, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.901691}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8728588104248047, "sum": 0.8728588104248047, "min": 0.8728588104248047}}, "EndTime": 1581006253.901753, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.901738}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.363455810546875, "sum": 1.363455810546875, "min": 1.363455810546875}}, "EndTime": 1581006253.901814, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.901796}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8192925262451172, "sum": 0.8192925262451172, "min": 0.8192925262451172}}, "EndTime": 1581006253.901875, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.901857}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0525624084472656, "sum": 1.0525624084472656, "min": 1.0525624084472656}}, "EndTime": 1581006253.901927, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.901912}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.750811538696289, "sum": 0.750811538696289, "min": 0.750811538696289}}, "EndTime": 1581006253.901986, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.901969}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8080010223388672, "sum": 0.8080010223388672, "min": 0.8080010223388672}}, "EndTime": 1581006253.902052, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.902035}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8131230926513672, "sum": 0.8131230926513672, "min": 0.8131230926513672}}, "EndTime": 1581006253.902117, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.902099}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6064065933227539, "sum": 0.6064065933227539, "min": 0.6064065933227539}}, "EndTime": 1581006253.90218, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.902162}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9851446533203125, "sum": 0.9851446533203125, "min": 0.9851446533203125}}, "EndTime": 1581006253.902253, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.902234}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7989055633544921, "sum": 0.7989055633544921, "min": 0.7989055633544921}}, "EndTime": 1581006253.902321, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.902303}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.16380859375, "sum": 1.16380859375, "min": 1.16380859375}}, "EndTime": 1581006253.902386, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.902368}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9831694793701172, "sum": 0.9831694793701172, "min": 0.9831694793701172}}, "EndTime": 1581006253.902458, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.902439}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8440264892578125, "sum": 0.8440264892578125, "min": 0.8440264892578125}}, "EndTime": 1581006253.902521, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.902503}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6961726379394532, "sum": 0.6961726379394532, "min": 0.6961726379394532}}, "EndTime": 1581006253.902583, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.902565}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6973097229003906, "sum": 0.6973097229003906, "min": 0.6973097229003906}}, "EndTime": 1581006253.902647, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.902635}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6948387908935547, "sum": 0.6948387908935547, "min": 0.6948387908935547}}, "EndTime": 1581006253.902701, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.902687}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9615062713623047, "sum": 0.9615062713623047, "min": 0.9615062713623047}}, "EndTime": 1581006253.902756, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.90274}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9526189422607422, "sum": 0.9526189422607422, "min": 0.9526189422607422}}, "EndTime": 1581006253.902826, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.902807}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.211592330932617, "sum": 1.211592330932617, "min": 1.211592330932617}}, "EndTime": 1581006253.902898, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.90288}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1163230895996095, "sum": 1.1163230895996095, "min": 1.1163230895996095}}, "EndTime": 1581006253.902965, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.902948}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1682733154296876, "sum": 1.1682733154296876, "min": 1.1682733154296876}}, "EndTime": 1581006253.903028, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.903011}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.4016249084472656, "sum": 1.4016249084472656, "min": 1.4016249084472656}}, "EndTime": 1581006253.903098, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.903079}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0063018798828125, "sum": 1.0063018798828125, "min": 1.0063018798828125}}, "EndTime": 1581006253.903162, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.903144}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0366583251953125, "sum": 1.0366583251953125, "min": 1.0366583251953125}}, "EndTime": 1581006253.903225, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.903207}
#
# [02/06/2020 16:24:13 INFO 140381932189504] #quality_metric: host=algo-1, epoch=1, train mse_objective <loss>=0.913081207275
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 73.76068987165179, "sum": 73.76068987165179, "min": 73.76068987165179}}, "EndTime": 1581006253.969362, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.969262}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 69.98485020228794, "sum": 69.98485020228794, "min": 69.98485020228794}}, "EndTime": 1581006253.969478, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.969455}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 103.12123325892857, "sum": 103.12123325892857, "min": 103.12123325892857}}, "EndTime": 1581006253.969584, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.969561}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 68.71133422851562, "sum": 68.71133422851562, "min": 68.71133422851562}}, "EndTime": 1581006253.969653, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.969636}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 59.66792515345982, "sum": 59.66792515345982, "min": 59.66792515345982}}, "EndTime": 1581006253.969756, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.969732}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 66.67736380440849, "sum": 66.67736380440849, "min": 66.67736380440849}}, "EndTime": 1581006253.969827, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.969808}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 70.67367989676339, "sum": 70.67367989676339, "min": 70.67367989676339}}, "EndTime": 1581006253.969928, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.969905}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 67.51543753487724, "sum": 67.51543753487724, "min": 67.51543753487724}}, "EndTime": 1581006253.969999, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.969979}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 76.90084402901786, "sum": 76.90084402901786, "min": 76.90084402901786}}, "EndTime": 1581006253.970099, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.970077}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 111.37972586495536, "sum": 111.37972586495536, "min": 111.37972586495536}}, "EndTime": 1581006253.970167, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.970148}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 68.58131626674107, "sum": 68.58131626674107, "min": 68.58131626674107}}, "EndTime": 1581006253.970266, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.970213}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 88.99415806361607, "sum": 88.99415806361607, "min": 88.99415806361607}}, "EndTime": 1581006253.970335, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.970317}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 67.20304216657367, "sum": 67.20304216657367, "min": 67.20304216657367}}, "EndTime": 1581006253.970434, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.970411}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 66.57984270368304, "sum": 66.57984270368304, "min": 66.57984270368304}}, "EndTime": 1581006253.970503, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.970485}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 62.963609967912944, "sum": 62.963609967912944, "min": 62.963609967912944}}, "EndTime": 1581006253.970597, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.970545}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 70.04546247209821, "sum": 70.04546247209821, "min": 70.04546247209821}}, "EndTime": 1581006253.970665, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.970646}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 83.92886788504464, "sum": 83.92886788504464, "min": 83.92886788504464}}, "EndTime": 1581006253.970757, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.97071}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 68.14447893415179, "sum": 68.14447893415179, "min": 68.14447893415179}}, "EndTime": 1581006253.970858, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.970836}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 98.18722970145089, "sum": 98.18722970145089, "min": 98.18722970145089}}, "EndTime": 1581006253.970923, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.970905}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 83.55630057198661, "sum": 83.55630057198661, "min": 83.55630057198661}}, "EndTime": 1581006253.971029, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.971008}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 56.266261509486604, "sum": 56.266261509486604, "min": 56.266261509486604}}, "EndTime": 1581006253.971094, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.971077}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 63.01839338030134, "sum": 63.01839338030134, "min": 63.01839338030134}}, "EndTime": 1581006253.971198, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.971176}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 55.661385672433035, "sum": 55.661385672433035, "min": 55.661385672433035}}, "EndTime": 1581006253.971262, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.971244}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 54.994798932756694, "sum": 54.994798932756694, "min": 54.994798932756694}}, "EndTime": 1581006253.971365, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.971344}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 83.58411516462054, "sum": 83.58411516462054, "min": 83.58411516462054}}, "EndTime": 1581006253.971428, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.971411}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 84.53657749720982, "sum": 84.53657749720982, "min": 84.53657749720982}}, "EndTime": 1581006253.97153, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.971509}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 97.27357700892857, "sum": 97.27357700892857, "min": 97.27357700892857}}, "EndTime": 1581006253.971594, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.971577}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 96.60043770926339, "sum": 96.60043770926339, "min": 96.60043770926339}}, "EndTime": 1581006253.971696, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.971674}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 89.53116280691964, "sum": 89.53116280691964, "min": 89.53116280691964}}, "EndTime": 1581006253.97176, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.971744}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 95.95803397042411, "sum": 95.95803397042411, "min": 95.95803397042411}}, "EndTime": 1581006253.971859, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.971838}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 84.65931047712054, "sum": 84.65931047712054, "min": 84.65931047712054}}, "EndTime": 1581006253.971926, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.971908}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 83.36570521763393, "sum": 83.36570521763393, "min": 83.36570521763393}}, "EndTime": 1581006253.972028, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1581006253.972005}
#
# ...
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9301171112060547, "sum": 0.9301171112060547, "min": 0.9301171112060547}}, "EndTime": 1581006255.17048, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1581006255.170462}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0172319793701172, "sum": 1.0172319793701172, "min": 1.0172319793701172}}, "EndTime": 1581006255.170548, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1581006255.170529}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8900587463378906, "sum": 0.8900587463378906, "min": 0.8900587463378906}}, "EndTime": 1581006255.170615, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1581006255.170597}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.073724365234375, "sum": 1.073724365234375, "min": 1.073724365234375}}, "EndTime": 1581006255.170675, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1581006255.170659}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.018908233642578, "sum": 1.018908233642578, "min": 1.018908233642578}}, "EndTime": 1581006255.170732, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1581006255.170718}
#
# [02/06/2020 16:24:15 INFO 140381932189504] #quality_metric: host=algo-1, epoch=14, train mse_objective <loss>=0.514897994995
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 43.693150111607146, "sum": 43.693150111607146, "min": 43.693150111607146}}, "EndTime": 1581006255.216835, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1581006255.216748}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 44.214730398995535, "sum": 44.214730398995535, "min": 44.214730398995535}}, "EndTime": 1581006255.216908, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1581006255.216895}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 55.06850324358259, "sum": 55.06850324358259, "min": 55.06850324358259}}, "EndTime": 1581006255.216959, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1581006255.216943}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 43.94823782784598, "sum": 43.94823782784598, "min": 43.94823782784598}}, "EndTime": 1581006255.21702, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1581006255.217004}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 22.140417916434153, "sum": 22.140417916434153, "min": 22.140417916434153}}, "EndTime": 1581006255.217079, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1581006255.217062}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 20.237226213727677, "sum": 20.237226213727677, "min": 20.237226213727677}}, "EndTime": 1581006255.217143, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1581006255.217126}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 19.460065569196427, "sum": 19.460065569196427, "min": 19.460065569196427}}, "EndTime": 1581006255.217202, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1581006255.217185}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 19.255824497767858, "sum": 19.255824497767858, "min": 19.255824497767858}}, "EndTime": 1581006255.217264, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1581006255.217247}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 50.516854422433035, "sum": 50.516854422433035, "min": 50.516854422433035}}, "EndTime": 1581006255.217326, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1581006255.217309}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 59.458343505859375, "sum": 59.458343505859375, "min": 59.458343505859375}}, "EndTime": 1581006255.217389, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1581006255.217371}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 45.8477783203125, "sum": 45.8477783203125, "min": 45.8477783203125}}, "EndTime": 1581006255.217451, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1581006255.217435}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 51.94472394670759, "sum": 51.94472394670759, "min": 51.94472394670759}}, "EndTime": 1581006255.217513, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1581006255.217495}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 19.663284301757812, "sum": 19.663284301757812, "min": 19.663284301757812}}, "EndTime": 1581006255.217574, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1581006255.217556}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 19.82977294921875, "sum": 19.82977294921875, "min": 19.82977294921875}}, "EndTime": 1581006255.217634, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1581006255.217616}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 22.063286917550222, "sum": 22.063286917550222, "min": 22.063286917550222}}, "EndTime": 1581006255.217696, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1581006255.217678}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 20.549231392996653, "sum": 20.549231392996653, "min": 20.549231392996653}}, "EndTime": 1581006255.217757, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1581006255.217739}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 50.72198922293527, "sum": 50.72198922293527, "min": 50.72198922293527}}, "EndTime": 1581006255.217818, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1581006255.2178}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 44.97768293108259, "sum": 44.97768293108259, "min": 44.97768293108259}}, "EndTime": 1581006255.217878, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1581006255.217861}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 60.445604596819194, "sum": 60.445604596819194, "min": 60.445604596819194}}, "EndTime": 1581006255.21794, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1581006255.217922}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 51.260689871651785, "sum": 51.260689871651785, "min": 51.260689871651785}}, "EndTime": 1581006255.218001, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1581006255.217984}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 41.59163120814732, "sum": 41.59163120814732, "min": 41.59163120814732}}, "EndTime": 1581006255.218059, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1581006255.218044}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 33.630506243024556, "sum": 33.630506243024556, "min": 33.630506243024556}}, "EndTime": 1581006255.218116, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1581006255.2181}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 40.289886474609375, "sum": 40.289886474609375, "min": 40.289886474609375}}, "EndTime": 1581006255.218178, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1581006255.218161}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 39.695792061941965, "sum": 39.695792061941965, "min": 39.695792061941965}}, "EndTime": 1581006255.21824, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1581006255.218222}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 86.05691964285714, "sum": 86.05691964285714, "min": 86.05691964285714}}, "EndTime": 1581006255.218301, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1581006255.218284}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 83.51272147042411, "sum": 83.51272147042411, "min": 83.51272147042411}}, "EndTime": 1581006255.218362, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1581006255.218344}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 79.69546072823661, "sum": 79.69546072823661, "min": 79.69546072823661}}, "EndTime": 1581006255.218424, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1581006255.218406}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 81.59296526227679, "sum": 81.59296526227679, "min": 81.59296526227679}}, "EndTime": 1581006255.218485, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1581006255.218468}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 86.12857491629464, "sum": 86.12857491629464, "min": 86.12857491629464}}, "EndTime": 1581006255.218546, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1581006255.218529}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 82.94884381975446, "sum": 82.94884381975446, "min": 82.94884381975446}}, "EndTime": 1581006255.218607, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1581006255.218589}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 89.5308837890625, "sum": 89.5308837890625, "min": 89.5308837890625}}, "EndTime": 1581006255.218668, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1581006255.218651}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 83.37203543526786, "sum": 83.37203543526786, "min": 83.37203543526786}}, "EndTime": 1581006255.218731, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1581006255.218712}
#
# [02/06/2020 16:24:15 INFO 140381932189504] #quality_metric: host=algo-1, epoch=14, validation mse_objective <loss>=43.6931501116
# [02/06/2020 16:24:15 INFO 140381932189504] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=mse_objective, value=19.2558244978
# [02/06/2020 16:24:15 INFO 140381932189504] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 2, "sum": 2.0, "min": 2}, "Number of Batches Since Last Reset": {"count": 1, "max": 2, "sum": 2.0, "min": 2}, "Number of Records Since Last Reset": {"count": 1, "max": 227, "sum": 227.0, "min": 227}, "Total Batches Seen": {"count": 1, "max": 33, "sum": 33.0, "min": 33}, "Total Records Seen": {"count": 1, "max": 3832, "sum": 3832.0, "min": 3832}, "Max Records Seen Between Resets": {"count": 1, "max": 227, "sum": 227.0, "min": 227}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1581006255.219779, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1581006255.140855}
#
# [02/06/2020 16:24:15 INFO 140381932189504] #throughput_metric: host=algo-1, train throughput=2871.01776393 records/second
# [02/06/2020 16:24:15 WARNING 140381932189504] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [02/06/2020 16:24:15 WARNING 140381932189504] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [02/06/2020 16:24:15 INFO 140381932189504] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=mse_objective, value=19.2558244978
# [02/06/2020 16:24:15 INFO 140381932189504] #validation_score (algo-1) : ('mse_objective', 19.166305541992188)
# [02/06/2020 16:24:15 INFO 140381932189504] #validation_score (algo-1) : ('mse', 19.166305541992188)
# [02/06/2020 16:24:15 INFO 140381932189504] #validation_score (algo-1) : ('absolute_loss', 3.321386064801897)
# [02/06/2020 16:24:15 INFO 140381932189504] #quality_metric: host=algo-1, validation mse_objective <loss>=19.166305542
# [02/06/2020 16:24:15 INFO 140381932189504] #quality_metric: host=algo-1, validation mse <loss>=19.166305542
# [02/06/2020 16:24:15 INFO 140381932189504] #quality_metric: host=algo-1, validation absolute_loss <loss>=3.3213860648
# [02/06/2020 16:24:15 INFO 140381932189504] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.01, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 1e-05}
# [02/06/2020 16:24:15 INFO 140381932189504] Saved checkpoint to "/tmp/tmpprJMnK/mx-mod-0000.params"
# [02/06/2020 16:24:15 INFO 140381932189504] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 1727.2870540618896, "sum": 1727.2870540618896, "min": 1727.2870540618896}, "finalize.time": {"count": 1, "max": 59.45086479187012, "sum": 59.45086479187012, "min": 59.45086479187012}, "initialize.time": {"count": 1, "max": 138.77296447753906, "sum": 138.77296447753906, "min": 138.77296447753906}, "check_early_stopping.time": {"count": 16, "max": 1.483917236328125, "sum": 11.605024337768555, "min": 0.21409988403320312}, "setuptime": {"count": 1, "max": 27.10413932800293, "sum": 27.10413932800293, "min": 27.10413932800293}, "update.time": {"count": 15, "max": 121.20413780212402, "sum": 1426.1195659637451, "min": 77.41498947143555}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1581006255.288659, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1581006253.647066}
#
#
# 2020-02-06 16:24:24 Uploading - Uploading generated training model
# 2020-02-06 16:24:24 Completed - Training job completed
# Training seconds: 38
# Billable seconds: 38

# %% [markdown]
# ## Step 6 (B): Deploy the trained model
#
# Similar to the XGBoost model, now that we've fit the model we need to deploy it. Also like the XGBoost model, we will use the lower level approach so that we have more control over the endpoint that gets created.
#
# ### Build the model
#
# Of course, before we can deploy the model, we need to first create it. The `fit` method that we used earlier created some model artifacts and we can use these to construct a model object.

# %%
# First, we create a unique model name
linear_model_name = "boston-update-linear-model" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

# We also need to tell SageMaker which container should be used for inference and where it should
# retrieve the model artifacts from. In our case, the linear-learner container that we used for training
# can also be used for inference.
linear_primary_container = {
    "Image": linear_container,
    "ModelDataUrl": linear.model_data
}

# And lastly we construct the SageMaker model
linear_model_info = session.sagemaker_client.create_model(
                                ModelName = linear_model_name,
                                ExecutionRoleArn = role,
                                PrimaryContainer = linear_primary_container)

# %% [markdown]
# ### Create the endpoint configuration
#
# Once we have the model we can start putting together the endpoint by creating an endpoint configuration.

# %%
# As before, we need to give our endpoint configuration a name which should be unique
linear_endpoint_config_name = "boston-linear-endpoint-config-" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

# And then we ask SageMaker to construct the endpoint configuration
linear_endpoint_config_info = session.sagemaker_client.create_endpoint_config(
                            EndpointConfigName = linear_endpoint_config_name,
                            ProductionVariants = [{
                                "InstanceType": "ml.m4.xlarge",
                                "InitialVariantWeight": 1,
                                "InitialInstanceCount": 1,
                                "ModelName": linear_model_name,
                                "VariantName": "Linear-Model"
                            }])

# %% [markdown]
# ### Deploy the endpoint
#
# Now that the endpoint configuration has been created, we can ask SageMaker to build our endpoint.
#
# **Note:** This is a friendly (repeated) reminder that you are about to deploy an endpoint. Make sure that you shut it down once you've finished with it!

# %%
# Again, we need a unique name for our endpoint
endpoint_name = "boston-update-endpoint-" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

# And then we can deploy our endpoint
endpoint_info = session.sagemaker_client.create_endpoint(
                    EndpointName = endpoint_name,
                    EndpointConfigName = linear_endpoint_config_name)

# %%
endpoint_dec = session.wait_for_endpoint(endpoint_name)
# Out:
# -------------------!

# %% [markdown]
# ## Step 7 (B): Use the model
#
# Just like with the XGBoost model, we will send some data to our endpoint to make sure that it is working properly. An important note is that the output format for the linear model is different from the XGBoost model.

# %%
response = session.sagemaker_runtime_client.invoke_endpoint(
                                                EndpointName = endpoint_name,
                                                ContentType = 'text/csv',
                                                Body = ','.join(map(str, X_test.values[0])))

# %%
pprint(response)
# Out:
# {'Body': <botocore.response.StreamingBody object at 0x7f0f3413c400>,
#  'ContentType': 'application/json',
#  'InvokedProductionVariant': 'Linear-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '47',
#                                       'content-type': 'application/json',
#                                       'date': 'Thu, 6 Feb 2020 16:34:28 GMT',
#                                       'x-amzn-invoked-production-variant': 'Linear-Model',
#                                       'x-amzn-requestid': 'cc6ad9be-9156-4253-accf-46df6c71b0b7'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': 'cc6ad9be-9156-4253-accf-46df6c71b0b7',
#                       'RetryAttempts': 0}}

# %%
result = response['Body'].read().decode("utf-8")

# %%
pprint(result)
# Out:
# '{"predictions": [{"score": 36.99541091918945}]}'

# %%
Y_test.values[0]
# Out:
# array([34.9])

# %% [markdown]
# ## Shut down the endpoint
#
# Now that we know that the Linear model's endpoint works, we can shut it down.

# %%
ession.sagemaker_client.delete_endpoint(EndpointName = endpoint_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-17a87ecaff95> in <module>()
# ----> 1 ession.sagemaker_client.delete_endpoint(EndpointName = endpoint_name)
#
# NameError: name 'ession' is not defined

# %% [markdown]
# ## Step 6 (C): Deploy a combined model
#
# So far we've constructed two separate models which we could deploy and use. Before we talk about how we can change a deployed endpoint from one configuration to another, let's consider a slightly different situation. Suppose that before we switch from using only the XGBoost model to only the Linear model, we first want to do something like an A-B test, where we send some of the incoming data to the XGBoost model and some of the data to the Linear model.
#
# Fortunately, SageMaker provides this functionality. And to actually get SageMaker to do this for us is not too different from deploying a model in the way that we've already done. The only difference is that we need to list more than one model in the production variants parameter of the endpoint configuration.
#
# A reasonable question to ask is, how much data is sent to each of the models that I list in the production variants parameter? The answer is that it depends on the weight set for each model.
#
# Suppose that we have $k$ models listed in the production variants and that each model $i$ is assigned the weight $w_i$. Then each model $i$ will receive $w_i / W$ of the traffic where $W = \sum_{i} w_i$.
#
# In our case, since we have two models, the linear model and the XGBoost model, and each model has weight 1, we see that each model will get 1 / (1 + 1) = 1/2 of the data sent to the endpoint.

# %%
# As before, we need to give our endpoint configuration a name which should be unique
combined_endpoint_config_name = "boston-combined-endpoint-config-" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

# And then we ask SageMaker to construct the endpoint configuration
combined_endpoint_config_info = session.sagemaker_client.create_endpoint_config(
                            EndpointConfigName = combined_endpoint_config_name,
                            ProductionVariants = [
                                { # First we include the linear model
                                    "InstanceType": "ml.m4.xlarge",
                                    "InitialVariantWeight": 1,
                                    "InitialInstanceCount": 1,
                                    "ModelName": linear_model_name,
                                    "VariantName": "Linear-Model"
                                }, { # And next we include the xgb model
                                    "InstanceType": "ml.m4.xlarge",
                                    "InitialVariantWeight": 1,
                                    "InitialInstanceCount": 1,
                                    "ModelName": xgb_model_name,
                                    "VariantName": "XGB-Model"
                                }])

# %% [markdown]
# Now that we've created the endpoint configuration, we can ask SageMaker to construct the endpoint.
#
# **Note:** This is a friendly (repeated) reminder that you are about to deploy an endpoint. Make sure that you shut it down once you've finished with it!

# %%
# Again, we need a unique name for our endpoint
endpoint_name = "boston-update-endpoint-" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

# And then we can deploy our endpoint
endpoint_info = session.sagemaker_client.create_endpoint(
                    EndpointName = endpoint_name,
                    EndpointConfigName = combined_endpoint_config_name)

# %%
endpoint_dec = session.wait_for_endpoint(endpoint_name)
# Out:
# -------------------!

# %% [markdown]
# ## Step 7 (C): Use the model
#
# Now that we've constructed an endpoint which sends data to both the XGBoost model and the linear model we can send some data to the endpoint and see what sort of results we get back.

# %%
response = session.sagemaker_runtime_client.invoke_endpoint(
                                                EndpointName = endpoint_name,
                                                ContentType = 'text/csv',
                                                Body = ','.join(map(str, X_test.values[0])))
pprint(response)
# Out:
# {'Body': <botocore.response.StreamingBody object at 0x7f0f340c43c8>,
#  'ContentType': 'application/json',
#  'InvokedProductionVariant': 'Linear-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '47',
#                                       'content-type': 'application/json',
#                                       'date': 'Thu, 6 Feb 2020 17:02:25 GMT',
#                                       'x-amzn-invoked-production-variant': 'Linear-Model',
#                                       'x-amzn-requestid': '8df25f85-0cca-411a-8589-3216448756f5'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '8df25f85-0cca-411a-8589-3216448756f5',
#                       'RetryAttempts': 0}}

# %% [markdown]
# Since looking at a single response doesn't give us a clear look at what is happening, we can instead take a look at a few different responses to our endpoint

# %%
for rec in range(10):
    response = session.sagemaker_runtime_client.invoke_endpoint(
                                                EndpointName = endpoint_name,
                                                ContentType = 'text/csv',
                                                Body = ','.join(map(str, X_test.values[rec])))
    pprint(response)
    result = response['Body'].read().decode("utf-8")
    print(result)
    print(Y_test.values[rec])
# Out:
# {'Body': <botocore.response.StreamingBody object at 0x7f0f34a7ed68>,
#  'ContentType': 'application/json',
#  'InvokedProductionVariant': 'Linear-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '47',
#                                       'content-type': 'application/json',
#                                       'date': 'Thu, 6 Feb 2020 17:02:30 GMT',
#                                       'x-amzn-invoked-production-variant': 'Linear-Model',
#                                       'x-amzn-requestid': '66830982-51ca-40f8-b009-d12596d13e9d'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '66830982-51ca-40f8-b009-d12596d13e9d',
#                       'RetryAttempts': 0}}
# {"predictions": [{"score": 36.99541091918945}]}
# [34.9]
# {'Body': <botocore.response.StreamingBody object at 0x7f0f34a7e3c8>,
#  'ContentType': 'text/csv; charset=utf-8',
#  'InvokedProductionVariant': 'XGB-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '13',
#                                       'content-type': 'text/csv; charset=utf-8',
#                                       'date': 'Thu, 6 Feb 2020 17:02:30 GMT',
#                                       'x-amzn-invoked-production-variant': 'XGB-Model',
#                                       'x-amzn-requestid': 'b46bb301-3938-4bf1-9432-e9a50aebd949'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': 'b46bb301-3938-4bf1-9432-e9a50aebd949',
#                       'RetryAttempts': 0}}
# 15.0529537201
# [14.5]
# {'Body': <botocore.response.StreamingBody object at 0x7f0f347f9ef0>,
#  'ContentType': 'application/json',
#  'InvokedProductionVariant': 'Linear-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '47',
#                                       'content-type': 'application/json',
#                                       'date': 'Thu, 6 Feb 2020 17:02:30 GMT',
#                                       'x-amzn-invoked-production-variant': 'Linear-Model',
#                                       'x-amzn-requestid': '7d8cf927-d5f0-49f0-ad40-b461553f4535'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '7d8cf927-d5f0-49f0-ad40-b461553f4535',
#                       'RetryAttempts': 0}}
# {"predictions": [{"score": 25.02942657470703}]}
# [21.4]
# {'Body': <botocore.response.StreamingBody object at 0x7f0f347f9b00>,
#  'ContentType': 'text/csv; charset=utf-8',
#  'InvokedProductionVariant': 'XGB-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '13',
#                                       'content-type': 'text/csv; charset=utf-8',
#                                       'date': 'Thu, 6 Feb 2020 17:02:30 GMT',
#                                       'x-amzn-invoked-production-variant': 'XGB-Model',
#                                       'x-amzn-requestid': '723cb6e5-d0b3-4eed-9325-6cbe3dc997a4'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '723cb6e5-d0b3-4eed-9325-6cbe3dc997a4',
#                       'RetryAttempts': 0}}
# 23.4852924347
# [22.8]
# {'Body': <botocore.response.StreamingBody object at 0x7f0f347f94a8>,
#  'ContentType': 'text/csv; charset=utf-8',
#  'InvokedProductionVariant': 'XGB-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '13',
#                                       'content-type': 'text/csv; charset=utf-8',
#                                       'date': 'Thu, 6 Feb 2020 17:02:30 GMT',
#                                       'x-amzn-invoked-production-variant': 'XGB-Model',
#                                       'x-amzn-requestid': 'c99f6e0b-5e10-4d9b-885c-3a205f8e51f0'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': 'c99f6e0b-5e10-4d9b-885c-3a205f8e51f0',
#                       'RetryAttempts': 0}}
# 26.7483768463
# [23.9]
# {'Body': <botocore.response.StreamingBody object at 0x7f0f347f9898>,
#  'ContentType': 'application/json',
#  'InvokedProductionVariant': 'Linear-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '48',
#                                       'content-type': 'application/json',
#                                       'date': 'Thu, 6 Feb 2020 17:02:30 GMT',
#                                       'x-amzn-invoked-production-variant': 'Linear-Model',
#                                       'x-amzn-requestid': '2d9074b3-233b-4823-9dbf-139e82853a86'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '2d9074b3-233b-4823-9dbf-139e82853a86',
#                       'RetryAttempts': 0}}
# {"predictions": [{"score": 35.929115295410156}]}
# [35.1]
# {'Body': <botocore.response.StreamingBody object at 0x7f0f337f3898>,
#  'ContentType': 'text/csv; charset=utf-8',
#  'InvokedProductionVariant': 'XGB-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '13',
#                                       'content-type': 'text/csv; charset=utf-8',
#                                       'date': 'Thu, 6 Feb 2020 17:02:30 GMT',
#                                       'x-amzn-invoked-production-variant': 'XGB-Model',
#                                       'x-amzn-requestid': 'a3ea5b22-ed84-4c43-8d8e-e0677d713c9b'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': 'a3ea5b22-ed84-4c43-8d8e-e0677d713c9b',
#                       'RetryAttempts': 0}}
# 18.0767745972
# [23.1]
# {'Body': <botocore.response.StreamingBody object at 0x7f0f340c4d68>,
#  'ContentType': 'application/json',
#  'InvokedProductionVariant': 'Linear-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '48',
#                                       'content-type': 'application/json',
#                                       'date': 'Thu, 6 Feb 2020 17:02:30 GMT',
#                                       'x-amzn-invoked-production-variant': 'Linear-Model',
#                                       'x-amzn-requestid': '2bc098d8-cb81-48c0-a340-3df17301e6f3'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '2bc098d8-cb81-48c0-a340-3df17301e6f3',
#                       'RetryAttempts': 0}}
# {"predictions": [{"score": 34.657623291015625}]}
# [31.6]
# {'Body': <botocore.response.StreamingBody object at 0x7f0f347f9d68>,
#  'ContentType': 'application/json',
#  'InvokedProductionVariant': 'Linear-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '48',
#                                       'content-type': 'application/json',
#                                       'date': 'Thu, 6 Feb 2020 17:02:30 GMT',
#                                       'x-amzn-invoked-production-variant': 'Linear-Model',
#                                       'x-amzn-requestid': '8c7b5a4e-336c-4ce0-ab89-a1eb347f89ea'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '8c7b5a4e-336c-4ce0-ab89-a1eb347f89ea',
#                       'RetryAttempts': 0}}
# {"predictions": [{"score": 13.482322692871094}]}
# [21.9]
# {'Body': <botocore.response.StreamingBody object at 0x7f0f347f9c18>,
#  'ContentType': 'application/json',
#  'InvokedProductionVariant': 'Linear-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '48',
#                                       'content-type': 'application/json',
#                                       'date': 'Thu, 6 Feb 2020 17:02:30 GMT',
#                                       'x-amzn-invoked-production-variant': 'Linear-Model',
#                                       'x-amzn-requestid': '3c02aa1e-a580-4a00-8e9b-c54273aace61'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '3c02aa1e-a580-4a00-8e9b-c54273aace61',
#                       'RetryAttempts': 0}}
# {"predictions": [{"score": 18.659679412841797}]}
# [12.7]

# %% [markdown]
# If at some point we aren't sure about the properties of a deployed endpoint, we can use the `describe_endpoint` function to get SageMaker to return a description of the deployed endpoint.

# %%
pprint(session.sagemaker_client.describe_endpoint(EndpointName=endpoint_name))
# Out:
# {'CreationTime': datetime.datetime(2020, 2, 6, 16, 38, 47, 402000, tzinfo=tzlocal()),
#  'EndpointArn': 'arn:aws:sagemaker:us-east-1:174814400447:endpoint/boston-update-endpoint-2020-02-06-16-38-47',
#  'EndpointConfigName': 'boston-combined-endpoint-config-2020-02-06-16-38-45',
#  'EndpointName': 'boston-update-endpoint-2020-02-06-16-38-47',
#  'EndpointStatus': 'InService',
#  'LastModifiedTime': datetime.datetime(2020, 2, 6, 16, 48, 4, 934000, tzinfo=tzlocal()),
#  'ProductionVariants': [{'CurrentInstanceCount': 1,
#                          'CurrentWeight': 1.0,
#                          'DeployedImages': [{'ResolutionTime': datetime.datetime(2020, 2, 6, 16, 38, 50, 195000, tzinfo=tzlocal()),
#                                              'ResolvedImage': '382416733822.dkr.ecr.us-east-1.amazonaws.com/linear-learner@sha256:0968670c29a5901e4cf38d3e690c3550e6c38539e0f004ccc79bb1e56d8b452b',
#                                              'SpecifiedImage': '382416733822.dkr.ecr.us-east-1.amazonaws.com/linear-learner:1'}],
#                          'DesiredInstanceCount': 1,
#                          'DesiredWeight': 1.0,
#                          'VariantName': 'Linear-Model'},
#                         {'CurrentInstanceCount': 1,
#                          'CurrentWeight': 1.0,
#                          'DeployedImages': [{'ResolutionTime': datetime.datetime(2020, 2, 6, 16, 38, 50, 412000, tzinfo=tzlocal()),
#                                              'ResolvedImage': '811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost@sha256:513e8442b35b9ecc9d326f85659f8e30b10e2cec096b863f04a9738baa9ebb57',
#                                              'SpecifiedImage': '811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost:1'}],
#                          'DesiredInstanceCount': 1,
#                          'DesiredWeight': 1.0,
#                          'VariantName': 'XGB-Model'}],
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '1162',
#                                       'content-type': 'application/x-amz-json-1.1',
#                                       'date': 'Thu, 06 Feb 2020 17:02:40 GMT',
#                                       'x-amzn-requestid': '08a46c53-ba19-4b73-9cb2-db95dc9653d6'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '08a46c53-ba19-4b73-9cb2-db95dc9653d6',
#                       'RetryAttempts': 0}}

# %% [markdown]
# ## Updating an Endpoint
#
# Now suppose that we've done our A-B test and the new linear model is working well enough. What we'd like to do now is to switch our endpoint from sending data to both the XGBoost model and the linear model to sending data only to the linear model.
#
# Of course, we don't really want to shut down the endpoint to do this as doing so would interrupt service to whoever depends on our endpoint. Instead, we can ask SageMaker to **update** an endpoint to a new endpoint configuration.
#
# What is actually happening is that SageMaker will set up a new endpoint with the new characteristics. Once this new endpoint is running, SageMaker will switch the old endpoint so that it now points at the newly deployed model, making sure that this happens seamlessly in the background.

# %%
session.sagemaker_client.update_endpoint(EndpointName=endpoint_name, EndpointConfigName=linear_endpoint_config_name)
# Out:
# {'EndpointArn': 'arn:aws:sagemaker:us-east-1:174814400447:endpoint/boston-update-endpoint-2020-02-06-16-38-47',
#  'ResponseMetadata': {'RequestId': 'fe9b9897-2a94-40a9-9b7f-65e104d5c4f6',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'fe9b9897-2a94-40a9-9b7f-65e104d5c4f6',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '110',
#    'date': 'Thu, 06 Feb 2020 17:02:43 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# To get a glimpse at what is going on, we can ask SageMaker to describe our in-use endpoint now, before the update process has completed. When we do so, we can see that the in-use endpoint still has the same characteristics it had before.

# %%
pprint(session.sagemaker_client.describe_endpoint(EndpointName=endpoint_name))
# Out:
# {'CreationTime': datetime.datetime(2020, 2, 6, 16, 38, 47, 402000, tzinfo=tzlocal()),
#  'EndpointArn': 'arn:aws:sagemaker:us-east-1:174814400447:endpoint/boston-update-endpoint-2020-02-06-16-38-47',
#  'EndpointConfigName': 'boston-combined-endpoint-config-2020-02-06-16-38-45',
#  'EndpointName': 'boston-update-endpoint-2020-02-06-16-38-47',
#  'EndpointStatus': 'Updating',
#  'LastModifiedTime': datetime.datetime(2020, 2, 6, 17, 2, 44, 152000, tzinfo=tzlocal()),
#  'ProductionVariants': [{'CurrentInstanceCount': 1,
#                          'CurrentWeight': 1.0,
#                          'DeployedImages': [{'ResolutionTime': datetime.datetime(2020, 2, 6, 16, 38, 50, 195000, tzinfo=tzlocal()),
#                                              'ResolvedImage': '382416733822.dkr.ecr.us-east-1.amazonaws.com/linear-learner@sha256:0968670c29a5901e4cf38d3e690c3550e6c38539e0f004ccc79bb1e56d8b452b',
#                                              'SpecifiedImage': '382416733822.dkr.ecr.us-east-1.amazonaws.com/linear-learner:1'}],
#                          'DesiredInstanceCount': 1,
#                          'DesiredWeight': 1.0,
#                          'VariantName': 'Linear-Model'},
#                         {'CurrentInstanceCount': 1,
#                          'CurrentWeight': 1.0,
#                          'DeployedImages': [{'ResolutionTime': datetime.datetime(2020, 2, 6, 16, 38, 50, 412000, tzinfo=tzlocal()),
#                                              'ResolvedImage': '811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost@sha256:513e8442b35b9ecc9d326f85659f8e30b10e2cec096b863f04a9738baa9ebb57',
#                                              'SpecifiedImage': '811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost:1'}],
#                          'DesiredInstanceCount': 1,
#                          'DesiredWeight': 1.0,
#                          'VariantName': 'XGB-Model'}],
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '1161',
#                                       'content-type': 'application/x-amz-json-1.1',
#                                       'date': 'Thu, 06 Feb 2020 17:02:46 GMT',
#                                       'x-amzn-requestid': '12f43981-20dc-404b-969b-b22de4b9ebb3'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '12f43981-20dc-404b-969b-b22de4b9ebb3',
#                       'RetryAttempts': 0}}

# %% [markdown]
# If we now wait for the update process to complete, and then ask SageMaker to describe the endpoint, it will return the characteristics of the new endpoint configuration.

# %%
endpoint_dec = session.wait_for_endpoint(endpoint_name)
# Out:
# -------------------!

# %%
pprint(session.sagemaker_client.describe_endpoint(EndpointName=endpoint_name))
# Out:
# {'CreationTime': datetime.datetime(2020, 2, 6, 16, 38, 47, 402000, tzinfo=tzlocal()),
#  'EndpointArn': 'arn:aws:sagemaker:us-east-1:174814400447:endpoint/boston-update-endpoint-2020-02-06-16-38-47',
#  'EndpointConfigName': 'boston-linear-endpoint-config-2020-02-06-16-24-56',
#  'EndpointName': 'boston-update-endpoint-2020-02-06-16-38-47',
#  'EndpointStatus': 'InService',
#  'LastModifiedTime': datetime.datetime(2020, 2, 6, 17, 12, 1, 688000, tzinfo=tzlocal()),
#  'ProductionVariants': [{'CurrentInstanceCount': 1,
#                          'CurrentWeight': 1.0,
#                          'DeployedImages': [{'ResolutionTime': datetime.datetime(2020, 2, 6, 17, 2, 46, 71000, tzinfo=tzlocal()),
#                                              'ResolvedImage': '382416733822.dkr.ecr.us-east-1.amazonaws.com/linear-learner@sha256:0968670c29a5901e4cf38d3e690c3550e6c38539e0f004ccc79bb1e56d8b452b',
#                                              'SpecifiedImage': '382416733822.dkr.ecr.us-east-1.amazonaws.com/linear-learner:1'}],
#                          'DesiredInstanceCount': 1,
#                          'DesiredWeight': 1.0,
#                          'VariantName': 'Linear-Model'}],
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '770',
#                                       'content-type': 'application/x-amz-json-1.1',
#                                       'date': 'Thu, 06 Feb 2020 17:16:30 GMT',
#                                       'x-amzn-requestid': 'c21d396d-ae02-4ff3-a80e-c91de5d642ab'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': 'c21d396d-ae02-4ff3-a80e-c91de5d642ab',
#                       'RetryAttempts': 0}}

# %% [markdown]
# ## Shut down the endpoint
#
# Now that we've finished, we need to make sure to shut down the endpoint.

# %%
session.sagemaker_client.delete_endpoint(EndpointName = endpoint_name)
# Out:
# {'ResponseMetadata': {'RequestId': 'dfa9d543-d1b8-4944-90fc-a2a505e691c8',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'dfa9d543-d1b8-4944-90fc-a2a505e691c8',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '0',
#    'date': 'Thu, 06 Feb 2020 17:16:32 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ## Optional: Clean up
#
# The default notebook instance on SageMaker doesn't have a lot of excess disk space available. As you continue to complete and execute notebooks you will eventually fill up this disk space, leading to errors which can be difficult to diagnose. Once you are completely finished using a notebook it is a good idea to remove the files that you created along the way. Of course, you can do this from the terminal or from the notebook hub if you would like. The cell below contains some commands to clean up the created files from within the notebook.

# %%
# First we will remove all of the files contained in the data_dir directory
# !rm $data_dir/*

# And then we delete the directory itself
# !rmdir $data_dir
